# %% [markdown]
# # Case3 extreme anisotropy with partial observation

# %% [markdown]
# ## Pacakages and Functions

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))   # the git/ folder, where utility.py lives
from utility import *  
import torch
import numpy as np
from inc_ensf import EnSF
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import math
from scipy.linalg import qr
from matplotlib.collections import LineCollection
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator

use_this = 'cuda:7'

# %%
def cov_generate(n,lambda_1):
    # n: dimension
    # 1. Direction of the line (e.g., all ones)
    v = np.ones(n)
    v /= np.linalg.norm(v)  # Normalize

    # 2. Create an orthonormal basis using QR decomposition
    # Stack v with random orthogonal vectors
    random_matrix = np.random.randn(n, n)
    random_matrix[:, 0] = v  # Set first column as v

    # QR gives orthonormal basis
    Q, _ = qr(random_matrix)  # Q is orthonormal, v is Q[:, 0]
    Lambda = np.diag([lambda_1 * 10**(-i) for i in range(n)]) 

    # 4. Build covariance matrix
    Sigma = Q @ Lambda @ Q.T  # Q * diag * Q^T
    Sigma += 1e-3 * np.eye(Sigma.shape[0])  # add jitter
    return Sigma

# %% [markdown]
# ## generate sample

# %%
#test question
N_dim=10
ensemble_size = 10000
main_var = 1000000
# generate samples
torch.manual_seed(100)
np.random.seed(8)
mean = torch.zeros(N_dim, device= use_this, dtype=torch.float32)
covariance_matrix = torch.tensor(cov_generate(N_dim,main_var), device= use_this, dtype=torch.float32)
mvn = torch.distributions.MultivariateNormal(mean, covariance_matrix)
test_sample = mvn.sample(sample_shape=(ensemble_size,))
test_sample[0] = 0
# print(test_sample.mean(dim=0),"\n",test_sample.T.cov(), "\n",torch.linalg.cond(covariance_matrix))

# %%
def to_numpy(a):
    return a.detach().cpu().numpy() if hasattr(a, "detach") else np.asarray(a)

test_all = to_numpy(test_sample)
# # =========================
# # 1) Build "result" samples by conditioning on x[d0] = x0_obs
# # =========================


Sigma = covariance_matrix.detach().cpu().numpy() if hasattr(covariance_matrix, "detach") else np.asarray(covariance_matrix)
n = Sigma.shape[0]

d0 = 0          # observed dimension
y  = 600     
sigma_obs = 5.00   


R = sigma_obs**2  # scalar

# Kalman gain (n,)
K = Sigma[:, d0] / (Sigma[d0, d0] + R)

# Posterior mean (n,)
mu_a = K * y

# Posterior covariance (n,n)
Sigma_a = Sigma - np.outer(Sigma[:, d0], Sigma[d0, :]) / (Sigma[d0, d0] + R)

# Sample posterior
rng = np.random.default_rng(123)
result_all = rng.multivariate_normal(mu_a, Sigma_a, size=ensemble_size)

for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        # choose 2D projection dims
        d0, d1 = dim_plot[0], dim_plot[1]
        # 2D arrays for plotting
        test   = test_all[:, [d0, d1]]
        result = result_all[:, [d0, d1]]

        # means/covs in 2D
        mean_test   = test.mean(axis=0)
        cov_test    = np.cov(test.T)

        mean_result = result.mean(axis=0)
        cov_result  = np.cov(result.T)
        ref_loc = mean_result.copy()
        # =========================
        # 2) Ellipse helper (yours)
        # =========================
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(np.maximum(eigvals, 0))
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)
            return ellipse

        # =========================
        # 3) Plot: prior vs post + path + ellipses
        # =========================
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)

        # scatter (keep s tiny; enlarge legend markers separately)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #     manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])
        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post (cond)", s=0.04, color="tab:orange")
        
        # covariance ellipses
        plot_cov_ellipse(cov_test,   mean_test,   ax, edgecolor="tab:blue", facecolor="none", linewidth=0.1,
                        label="Cov ellipse prior")
        plot_cov_ellipse(cov_result, mean_result, ax, edgecolor="tab:orange",  facecolor="none", linewidth=0.1,
                        label="Cov ellipse post")
        
        ax.axis("equal")

        ax.set_xlim(-100, 880)
        ax.set_ylim(-100, 800)
        ax.xaxis.set_major_locator(MultipleLocator(300))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(300))   # y-axis tick every 5

        ax.tick_params(axis='both', which='major', labelsize=24)
        ax.grid(alpha = 0.3)
        #ax.legend(markerscale=25)  # enlarge legend markers only
        plt.tight_layout()
        sigma_str = "mix"#f"{sigma_obs:g}".replace(".", "p")
        plt.show()
        plt.close()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## EnSF

# %% [markdown]
# ### ensemble-mean paths 100 iterations

# %%
testensf = EnSF(n_dim = N_dim, ensemble_size = ensemble_size ,eps_alpha=0.01, eps_beta= 0.00, device= use_this ,obs_sigma = 5, euler_steps = 1)
result1 = testensf.RSDE_inc(obs=600, x0=0, x_prior=test_sample.clone(), time_steps=100, ens_cov=covariance_matrix/25000, sparse_idx=[0],cov_scale = 25000, tau_scale = 1000) 

#path mean
for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        # choose 2D projection dims
        d0, d1 = dim_plot[0], dim_plot[1]
        # 2D arrays for plotting
        test   = test_all[:, [d0, d1]]
        result = result_all[:, [d0, d1]]

        # means/covs in 2D
        mean_test   = test.mean(axis=0)
        cov_test    = np.cov(test.T)

        mean_result = result.mean(axis=0)
        cov_result  = np.cov(result.T)
        ref_loc = mean_result.copy()
        # =========================
        # 2) Ellipse helper (yours)
        # =========================
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(np.maximum(eigvals, 0))
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)
            return ellipse

        # =========================
        # 3) Plot: prior vs post + path + ellipses
        # =========================
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)

        # scatter (keep s tiny; enlarge legend markers separately)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #     manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])
        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post (cond)", s=0.04, color="tab:orange")
        
        # covariance ellipses
        plot_cov_ellipse(cov_test,   mean_test,   ax, edgecolor="tab:blue", facecolor="none", linewidth=0.1,
                        label="Cov ellipse prior")
        plot_cov_ellipse(cov_result, mean_result, ax, edgecolor="tab:orange",  facecolor="none", linewidth=0.1,
                        label="Cov ellipse post")
        
        ax.axis("equal")

        ax.set_xlim(-100, 880)
        ax.set_ylim(-100, 800)
        ax.xaxis.set_major_locator(MultipleLocator(300))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(300))   # y-axis tick every 5

        ax.tick_params(axis='both', which='major', labelsize=24)
        ax.grid(alpha = 0.3)
        #ax.legend(markerscale=25)  # enlarge legend markers only
        plt.tight_layout()
        sigma_str = "mix"#f"{sigma_obs:g}".replace(".", "p")
        plt.show()
        plt.close()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## 3DEnVar

# %% [markdown]
# ### ensemble-mean paths

# %%
#sparse obs
H = lambda x: x
obs = torch.tensor((600))
# Create EnVar instance
# replace with __all__ = ['EnVar3D', 'CVT3dEnVar', 'CVT3dEnVarPerturbedObs', 'EnVar3DPerturbedObs']
envar = EnVar3DPerturbedObs(H=H, y_obs=obs, B = covariance_matrix, R=torch.eye(N_dim)*25.0, Xb= test_sample.clone(),obs_idx=[0], learning_rate=0.005, max_iterations=50000, convergence_threshold=1e-6,device=use_this)
x_analysis,nan_idx, x_path = envar.run()

#path mean
plot_endpont = -1
x = (x_path).cpu().detach().numpy()
for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        rotated_test_sample = test_sample[:,dim_plot] 
        d0, d1 = dim_plot[0], dim_plot[1]
        ref_loc = result_all[:, [d0, d1]].mean(axis=0)
        test = rotated_test_sample.cpu().numpy()  #rotated_test_sample
        result = x[plot_endpont][:, dim_plot]
        # Define the 2D covariance matrix
        cov_test = np.cov(test.T)
        cov_result = np.cov(result.T)

        # Mean of the distribution (center of the ellipse)
        mean_test = test.mean(axis = 0)
        mean_result = result.mean(axis = 0)
        # Generate samples from the multivariate normal distribution

        # Plot the samples
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #   manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])

        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post", s=0.04, color = "tab:orange")

        # Function to draw the covariance ellipse
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(eigvals)
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)

        # Draw the ellipse
        plot_cov_ellipse(cov_test,mean_test, ax, edgecolor='tab:blue', facecolor='none', linewidth=0.1, label='Covariance Ellipse Prior')
        plot_cov_ellipse(cov_result,mean_result, ax, edgecolor='tab:orange', facecolor='none', linewidth=0.1, label='Covariance Ellipse post')
        #mark the reference point
        ensf_path = x[:plot_endpont,:,dim_plot].mean(axis=1)
        px, py = ensf_path[:, 0], ensf_path[:, 1]
        plt.plot(px, py,'--',linewidth=1,color = "black", label='EnSF')

        def arrow_at(ax, x, y, idx, color='black', size=58, lw=1, back=50, tail_pt=0.5):
            """Open '>' arrowhead at point idx, oriented along the local path direction."""
            j = max(idx - back, 0)
            d = np.array([x[idx] - x[j], y[idx] - y[j]])
            d /= np.linalg.norm(d) + 1e-12
            ax.annotate('', xy=(x[idx], y[idx]),
                        xytext=(-tail_pt * d[0], -tail_pt * d[1]), textcoords='offset points',
                        arrowprops=dict(arrowstyle='->', color=color, mutation_scale=size,
                                        lw=lw, shrinkA=0, shrinkB=0), zorder=6)


        ax.scatter(mean_test[0], mean_test[1], marker='^', alpha=1, color ="tab:blue" ,label="reference", s=400)
        ax.scatter(mean_result[0], mean_result[1], marker='s',alpha=1, color ="black" ,label="reference", s=200)
        ax.axis('equal')

        ax.set_xlim(-100, 880)
        ax.set_ylim(-100, 800)
        ax.xaxis.set_major_locator(MultipleLocator(300))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(300))   # y-axis tick every 5
        ax.tick_params(axis='both', which='major', labelsize=24)

        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
        plt.close()
# Out:
# Iteration 1: Cost = 9363.722656
# Iteration 2: Cost = 9359.977539
# Iteration 3: Cost = 9356.233398
# Iteration 4: Cost = 9352.491211
# Iteration 5: Cost = 9348.751953
# Iteration 6: Cost = 9345.012695
# Iteration 7: Cost = 9341.274414
# Iteration 8: Cost = 9337.539062
# Iteration 9: Cost = 9333.803711
# Iteration 10: Cost = 9330.071289
# Iteration 11: Cost = 9326.340820
# Iteration 12: Cost = 9322.610352
# Iteration 13: Cost = 9318.881836
# Iteration 14: Cost = 9315.155273
# Iteration 15: Cost = 9311.428711
# Iteration 16: Cost = 9307.705078
# Iteration 17: Cost = 9303.983398
# Iteration 18: Cost = 9300.261719
# Iteration 19: Cost = 9296.541992
# Iteration 20: Cost = 9292.824219
# Iteration 21: Cost = 9289.108398
# Iteration 22: Cost = 9285.394531
# Iteration 23: Cost = 9281.680664
# Iteration 24: Cost = 9277.968750
# Iteration 25: Cost = 9274.257812
# Iteration 26: Cost = 9270.549805
# Iteration 27: Cost = 9266.841797
# Iteration 28: Cost = 9263.136719
# Iteration 29: Cost = 9259.431641
# Iteration 30: Cost = 9255.729492
# Iteration 31: Cost = 9252.027344
# Iteration 32: Cost = 9248.328125
# Iteration 33: Cost = 9244.629883
# Iteration 34: Cost = 9240.933594
# Iteration 35: Cost = 9237.238281
# Iteration 36: Cost = 9233.544922
# Iteration 37: Cost = 9229.851562
# Iteration 38: Cost = 9226.161133
# Iteration 39: Cost = 9222.472656
# Iteration 40: Cost = 9218.784180
# Iteration 41: Cost = 9215.098633
# Iteration 42: Cost = 9211.413086
# Iteration 43: Cost = 9207.729492
# Iteration 44: Cost = 9204.047852
# Iteration 45: Cost = 9200.368164
# Iteration 46: Cost = 9196.689453
# Iteration 47: Cost = 9193.011719
# Iteration 48: Cost = 9189.335938
# Iteration 49: Cost = 9185.661133
# Iteration 50: Cost = 9181.988281
# Iteration 51: Cost = 9178.318359
# Iteration 52: Cost = 9174.647461
# Iteration 53: Cost = 9170.978516
# Iteration 54: Cost = 9167.311523
# Iteration 55: Cost = 9163.646484
# Iteration 56: Cost = 9159.982422
# Iteration 57: Cost = 9156.320312
# Iteration 58: Cost = 9152.660156
# Iteration 59: Cost = 9149.000977
# Iteration 60: Cost = 9145.341797
# Iteration 61: Cost = 9141.686523
# Iteration 62: Cost = 9138.031250
# Iteration 63: Cost = 9134.376953
# Iteration 64: Cost = 9130.725586
# Iteration 65: Cost = 9127.074219
# Iteration 66: Cost = 9123.425781
# Iteration 67: Cost = 9119.777344
# Iteration 68: Cost = 9116.132812
# Iteration 69: Cost = 9112.487305
# Iteration 70: Cost = 9108.844727
# Iteration 71: Cost = 9105.203125
# Iteration 72: Cost = 9101.562500
# Iteration 73: Cost = 9097.924805
# Iteration 74: Cost = 9094.286133
# Iteration 75: Cost = 9090.651367
# Iteration 76: Cost = 9087.015625
# Iteration 77: Cost = 9083.383789
# Iteration 78: Cost = 9079.751953
# Iteration 79: Cost = 9076.123047
# Iteration 80: Cost = 9072.494141
# Iteration 81: Cost = 9068.867188
# Iteration 82: Cost = 9065.242188
# Iteration 83: Cost = 9061.618164
# Iteration 84: Cost = 9057.996094
# Iteration 85: Cost = 9054.374023
# Iteration 86: Cost = 9050.754883
# Iteration 87: Cost = 9047.136719
# Iteration 88: Cost = 9043.519531
# Iteration 89: Cost = 9039.905273
# Iteration 90: Cost = 9036.291016
# Iteration 91: Cost = 9032.678711
# Iteration 92: Cost = 9029.068359
# Iteration 93: Cost = 9025.458984
# Iteration 94: Cost = 9021.850586
# Iteration 95: Cost = 9018.245117
# Iteration 96: Cost = 9014.640625
# Iteration 97: Cost = 9011.036133
# Iteration 98: Cost = 9007.434570
# Iteration 99: Cost = 9003.833984
# Iteration 100: Cost = 9000.235352
# Iteration 101: Cost = 8996.637695
# Iteration 102: Cost = 8993.041016
# Iteration 103: Cost = 8989.447266
# Iteration 104: Cost = 8985.854492
# Iteration 105: Cost = 8982.261719
# Iteration 106: Cost = 8978.671875
# Iteration 107: Cost = 8975.083984
# Iteration 108: Cost = 8971.496094
# Iteration 109: Cost = 8967.909180
# Iteration 110: Cost = 8964.325195
# Iteration 111: Cost = 8960.742188
# Iteration 112: Cost = 8957.161133
# Iteration 113: Cost = 8953.581055
# Iteration 114: Cost = 8950.001953
# Iteration 115: Cost = 8946.425781
# Iteration 116: Cost = 8942.849609
# Iteration 117: Cost = 8939.275391
# Iteration 118: Cost = 8935.702148
# Iteration 119: Cost = 8932.130859
# Iteration 120: Cost = 8928.561523
# Iteration 121: Cost = 8924.993164
# Iteration 122: Cost = 8921.425781
# Iteration 123: Cost = 8917.860352
# Iteration 124: Cost = 8914.295898
# Iteration 125: Cost = 8910.733398
# Iteration 126: Cost = 8907.171875
# Iteration 127: Cost = 8903.612305
# Iteration 128: Cost = 8900.053711
# Iteration 129: Cost = 8896.496094
# Iteration 130: Cost = 8892.941406
# Iteration 131: Cost = 8889.386719
# Iteration 132: Cost = 8885.834961
# Iteration 133: Cost = 8882.284180
# Iteration 134: Cost = 8878.733398
# Iteration 135: Cost = 8875.185547
# Iteration 136: Cost = 8871.638672
# Iteration 137: Cost = 8868.093750
# Iteration 138: Cost = 8864.549805
# Iteration 139: Cost = 8861.007812
# Iteration 140: Cost = 8857.465820
# Iteration 141: Cost = 8853.925781
# Iteration 142: Cost = 8850.388672
# Iteration 143: Cost = 8846.851562
# Iteration 144: Cost = 8843.316406
# Iteration 145: Cost = 8839.782227
# Iteration 146: Cost = 8836.249023
# Iteration 147: Cost = 8832.719727
# Iteration 148: Cost = 8829.189453
# Iteration 149: Cost = 8825.661133
# Iteration 150: Cost = 8822.133789
# Iteration 151: Cost = 8818.609375
# Iteration 152: Cost = 8815.085938
# Iteration 153: Cost = 8811.562500
# Iteration 154: Cost = 8808.042969
# Iteration 155: Cost = 8804.522461
# Iteration 156: Cost = 8801.004883
# Iteration 157: Cost = 8797.487305
# Iteration 158: Cost = 8793.972656
# Iteration 159: Cost = 8790.458984
# Iteration 160: Cost = 8786.945312
# Iteration 161: Cost = 8783.434570
# Iteration 162: Cost = 8779.925781
# Iteration 163: Cost = 8776.416992
# Iteration 164: Cost = 8772.910156
# Iteration 165: Cost = 8769.405273
# Iteration 166: Cost = 8765.902344
# Iteration 167: Cost = 8762.399414
# Iteration 168: Cost = 8758.897461
# Iteration 169: Cost = 8755.399414
# Iteration 170: Cost = 8751.900391
# Iteration 171: Cost = 8748.403320
# Iteration 172: Cost = 8744.908203
# Iteration 173: Cost = 8741.414062
# Iteration 174: Cost = 8737.920898
# Iteration 175: Cost = 8734.430664
# Iteration 176: Cost = 8730.940430
# Iteration 177: Cost = 8727.452148
# Iteration 178: Cost = 8723.965820
# Iteration 179: Cost = 8720.480469
# Iteration 180: Cost = 8716.996094
# Iteration 181: Cost = 8713.514648
# Iteration 182: Cost = 8710.033203
# Iteration 183: Cost = 8706.553711
# Iteration 184: Cost = 8703.075195
# Iteration 185: Cost = 8699.597656
# Iteration 186: Cost = 8696.123047
# Iteration 187: Cost = 8692.647461
# Iteration 188: Cost = 8689.175781
# Iteration 189: Cost = 8685.704102
# Iteration 190: Cost = 8682.234375
# Iteration 191: Cost = 8678.766602
# Iteration 192: Cost = 8675.298828
# Iteration 193: Cost = 8671.833008
# Iteration 194: Cost = 8668.369141
# Iteration 195: Cost = 8664.906250
# Iteration 196: Cost = 8661.443359
# Iteration 197: Cost = 8657.984375
# Iteration 198: Cost = 8654.526367
# Iteration 199: Cost = 8651.068359
# Iteration 200: Cost = 8647.612305
# Iteration 201: Cost = 8644.158203
# Iteration 202: Cost = 8640.705078
# Iteration 203: Cost = 8637.252930
# Iteration 204: Cost = 8633.802734
# Iteration 205: Cost = 8630.354492
# Iteration 206: Cost = 8626.907227
# Iteration 207: Cost = 8623.460938
# Iteration 208: Cost = 8620.015625
# Iteration 209: Cost = 8616.573242
# Iteration 210: Cost = 8613.131836
# Iteration 211: Cost = 8609.691406
# Iteration 212: Cost = 8606.251953
# Iteration 213: Cost = 8602.814453
# Iteration 214: Cost = 8599.377930
# Iteration 215: Cost = 8595.943359
# Iteration 216: Cost = 8592.509766
# Iteration 217: Cost = 8589.078125
# Iteration 218: Cost = 8585.646484
# Iteration 219: Cost = 8582.217773
# Iteration 220: Cost = 8578.790039
# Iteration 221: Cost = 8575.363281
# Iteration 222: Cost = 8571.938477
# Iteration 223: Cost = 8568.514648
# Iteration 224: Cost = 8565.091797
# Iteration 225: Cost = 8561.670898
# Iteration 226: Cost = 8558.250977
# Iteration 227: Cost = 8554.833008
# Iteration 228: Cost = 8551.416992
# Iteration 229: Cost = 8548.000977
# Iteration 230: Cost = 8544.586914
# Iteration 231: Cost = 8541.173828
# Iteration 232: Cost = 8537.763672
# Iteration 233: Cost = 8534.353516
# Iteration 234: Cost = 8530.945312
# Iteration 235: Cost = 8527.538086
# Iteration 236: Cost = 8524.132812
# Iteration 237: Cost = 8520.727539
# Iteration 238: Cost = 8517.324219
# Iteration 239: Cost = 8513.924805
# Iteration 240: Cost = 8510.523438
# Iteration 241: Cost = 8507.125000
# Iteration 242: Cost = 8503.727539
# Iteration 243: Cost = 8500.331055
# Iteration 244: Cost = 8496.936523
# Iteration 245: Cost = 8493.543945
# Iteration 246: Cost = 8490.151367
# Iteration 247: Cost = 8486.760742
# Iteration 248: Cost = 8483.372070
# Iteration 249: Cost = 8479.983398
# Iteration 250: Cost = 8476.598633
# Iteration 251: Cost = 8473.212891
# Iteration 252: Cost = 8469.829102
# Iteration 253: Cost = 8466.446289
# Iteration 254: Cost = 8463.065430
# Iteration 255: Cost = 8459.686523
# Iteration 256: Cost = 8456.307617
# Iteration 257: Cost = 8452.930664
# Iteration 258: Cost = 8449.556641
# Iteration 259: Cost = 8446.182617
# Iteration 260: Cost = 8442.809570
# Iteration 261: Cost = 8439.438477
# Iteration 262: Cost = 8436.068359
# Iteration 263: Cost = 8432.700195
# Iteration 264: Cost = 8429.333008
# Iteration 265: Cost = 8425.965820
# Iteration 266: Cost = 8422.602539
# Iteration 267: Cost = 8419.239258
# Iteration 268: Cost = 8415.876953
# Iteration 269: Cost = 8412.516602
# Iteration 270: Cost = 8409.157227
# Iteration 271: Cost = 8405.799805
# Iteration 272: Cost = 8402.444336
# Iteration 273: Cost = 8399.089844
# Iteration 274: Cost = 8395.735352
# Iteration 275: Cost = 8392.383789
# Iteration 276: Cost = 8389.032227
# Iteration 277: Cost = 8385.682617
# Iteration 278: Cost = 8382.334961
# Iteration 279: Cost = 8378.988281
# Iteration 280: Cost = 8375.642578
# Iteration 281: Cost = 8372.297852
# Iteration 282: Cost = 8368.957031
# Iteration 283: Cost = 8365.614258
# Iteration 284: Cost = 8362.275391
# Iteration 285: Cost = 8358.935547
# Iteration 286: Cost = 8355.598633
# Iteration 287: Cost = 8352.262695
# Iteration 288: Cost = 8348.928711
# Iteration 289: Cost = 8345.594727
# Iteration 290: Cost = 8342.263672
# Iteration 291: Cost = 8338.932617
# Iteration 292: Cost = 8335.604492
# Iteration 293: Cost = 8332.276367
# Iteration 294: Cost = 8328.949219
# Iteration 295: Cost = 8325.624023
# Iteration 296: Cost = 8322.300781
# Iteration 297: Cost = 8318.978516
# Iteration 298: Cost = 8315.657227
# Iteration 299: Cost = 8312.336914
# Iteration 300: Cost = 8309.018555
# Iteration 301: Cost = 8305.702148
# Iteration 302: Cost = 8302.386719
# Iteration 303: Cost = 8299.072266
# Iteration 304: Cost = 8295.758789
# Iteration 305: Cost = 8292.448242
# Iteration 306: Cost = 8289.137695
# Iteration 307: Cost = 8285.829102
# Iteration 308: Cost = 8282.521484
# Iteration 309: Cost = 8279.213867
# Iteration 310: Cost = 8275.910156
# Iteration 311: Cost = 8272.606445
# Iteration 312: Cost = 8269.303711
# Iteration 313: Cost = 8266.002930
# Iteration 314: Cost = 8262.704102
# Iteration 315: Cost = 8259.406250
# Iteration 316: Cost = 8256.108398
# Iteration 317: Cost = 8252.813477
# Iteration 318: Cost = 8249.519531
# Iteration 319: Cost = 8246.226562
# Iteration 320: Cost = 8242.934570
# Iteration 321: Cost = 8239.644531
# Iteration 322: Cost = 8236.355469
# Iteration 323: Cost = 8233.068359
# Iteration 324: Cost = 8229.782227
# Iteration 325: Cost = 8226.497070
# Iteration 326: Cost = 8223.213867
# Iteration 327: Cost = 8219.930664
# Iteration 328: Cost = 8216.651367
# Iteration 329: Cost = 8213.371094
# Iteration 330: Cost = 8210.093750
# Iteration 331: Cost = 8206.815430
# Iteration 332: Cost = 8203.541016
# Iteration 333: Cost = 8200.266602
# Iteration 334: Cost = 8196.993164
# Iteration 335: Cost = 8193.722656
# Iteration 336: Cost = 8190.451660
# Iteration 337: Cost = 8187.183105
# Iteration 338: Cost = 8183.915039
# Iteration 339: Cost = 8180.649414
# Iteration 340: Cost = 8177.383789
# Iteration 341: Cost = 8174.121582
# Iteration 342: Cost = 8170.858887
# Iteration 343: Cost = 8167.598145
# Iteration 344: Cost = 8164.337402
# Iteration 345: Cost = 8161.079590
# Iteration 346: Cost = 8157.822754
# Iteration 347: Cost = 8154.567871
# Iteration 348: Cost = 8151.313477
# Iteration 349: Cost = 8148.060547
# Iteration 350: Cost = 8144.807617
# Iteration 351: Cost = 8141.558105
# Iteration 352: Cost = 8138.309570
# Iteration 353: Cost = 8135.061523
# Iteration 354: Cost = 8131.815918
# Iteration 355: Cost = 8128.569336
# Iteration 356: Cost = 8125.326172
# Iteration 357: Cost = 8122.083984
# Iteration 358: Cost = 8118.842773
# Iteration 359: Cost = 8115.603027
# Iteration 360: Cost = 8112.364746
# Iteration 361: Cost = 8109.126953
# Iteration 362: Cost = 8105.891113
# Iteration 363: Cost = 8102.656738
# Iteration 364: Cost = 8099.423828
# Iteration 365: Cost = 8096.191895
# Iteration 366: Cost = 8092.960449
# Iteration 367: Cost = 8089.730957
# Iteration 368: Cost = 8086.503906
# Iteration 369: Cost = 8083.277344
# Iteration 370: Cost = 8080.050781
# Iteration 371: Cost = 8076.827637
# Iteration 372: Cost = 8073.604492
# Iteration 373: Cost = 8070.383789
# Iteration 374: Cost = 8067.163574
# Iteration 375: Cost = 8063.945312
# Iteration 376: Cost = 8060.727051
# Iteration 377: Cost = 8057.511230
# Iteration 378: Cost = 8054.295898
# Iteration 379: Cost = 8051.082031
# Iteration 380: Cost = 8047.870117
# Iteration 381: Cost = 8044.659180
# Iteration 382: Cost = 8041.449219
# Iteration 383: Cost = 8038.241211
# Iteration 384: Cost = 8035.034180
# Iteration 385: Cost = 8031.828613
# Iteration 386: Cost = 8028.624023
# Iteration 387: Cost = 8025.420410
# Iteration 388: Cost = 8022.219238
# Iteration 389: Cost = 8019.017578
# Iteration 390: Cost = 8015.818848
# Iteration 391: Cost = 8012.620605
# Iteration 392: Cost = 8009.423828
# Iteration 393: Cost = 8006.228516
# Iteration 394: Cost = 8003.034180
# Iteration 395: Cost = 7999.841309
# Iteration 396: Cost = 7996.650391
# Iteration 397: Cost = 7993.460449
# Iteration 398: Cost = 7990.270996
# Iteration 399: Cost = 7987.083008
# Iteration 400: Cost = 7983.897461
# Iteration 401: Cost = 7980.712402
# Iteration 402: Cost = 7977.527832
# Iteration 403: Cost = 7974.347168
# Iteration 404: Cost = 7971.165527
# Iteration 405: Cost = 7967.985352
# Iteration 406: Cost = 7964.806152
# Iteration 407: Cost = 7961.629395
# Iteration 408: Cost = 7958.453613
# Iteration 409: Cost = 7955.278320
# Iteration 410: Cost = 7952.105469
# Iteration 411: Cost = 7948.932617
# Iteration 412: Cost = 7945.763184
# Iteration 413: Cost = 7942.593262
# Iteration 414: Cost = 7939.424805
# Iteration 415: Cost = 7936.257324
# Iteration 416: Cost = 7933.092773
# Iteration 417: Cost = 7929.927734
# Iteration 418: Cost = 7926.764648
# Iteration 419: Cost = 7923.602051
# Iteration 420: Cost = 7920.442383
# Iteration 421: Cost = 7917.283203
# Iteration 422: Cost = 7914.124512
# Iteration 423: Cost = 7910.967773
# Iteration 424: Cost = 7907.812500
# Iteration 425: Cost = 7904.659180
# Iteration 426: Cost = 7901.506348
# Iteration 427: Cost = 7898.353516
# Iteration 428: Cost = 7895.203613
# Iteration 429: Cost = 7892.054199
# Iteration 430: Cost = 7888.907227
# Iteration 431: Cost = 7885.760742
# Iteration 432: Cost = 7882.615723
# Iteration 433: Cost = 7879.471191
# Iteration 434: Cost = 7876.329590
# Iteration 435: Cost = 7873.187012
# Iteration 436: Cost = 7870.047852
# Iteration 437: Cost = 7866.908691
# Iteration 438: Cost = 7863.770996
# Iteration 439: Cost = 7860.634277
# Iteration 440: Cost = 7857.500000
# Iteration 441: Cost = 7854.366211
# Iteration 442: Cost = 7851.233398
# Iteration 443: Cost = 7848.102051
# Iteration 444: Cost = 7844.972656
# Iteration 445: Cost = 7841.843750
# Iteration 446: Cost = 7838.716797
# Iteration 447: Cost = 7835.590332
# Iteration 448: Cost = 7832.465332
# Iteration 449: Cost = 7829.342285
# Iteration 450: Cost = 7826.219727
# Iteration 451: Cost = 7823.099121
# Iteration 452: Cost = 7819.979004
# Iteration 453: Cost = 7816.860840
# Iteration 454: Cost = 7813.743164
# Iteration 455: Cost = 7810.626953
# Iteration 456: Cost = 7807.512695
# Iteration 457: Cost = 7804.399902
# Iteration 458: Cost = 7801.287109
# Iteration 459: Cost = 7798.175781
# Iteration 460: Cost = 7795.066895
# Iteration 461: Cost = 7791.958008
# Iteration 462: Cost = 7788.851074
# Iteration 463: Cost = 7785.745605
# Iteration 464: Cost = 7782.640625
# Iteration 465: Cost = 7779.537598
# Iteration 466: Cost = 7776.435059
# Iteration 467: Cost = 7773.333984
# Iteration 468: Cost = 7770.234863
# Iteration 469: Cost = 7767.137207
# Iteration 470: Cost = 7764.040039
# Iteration 471: Cost = 7760.943848
# Iteration 472: Cost = 7757.849609
# Iteration 473: Cost = 7754.755859
# Iteration 474: Cost = 7751.663574
# Iteration 475: Cost = 7748.572754
# Iteration 476: Cost = 7745.484375
# Iteration 477: Cost = 7742.395020
# Iteration 478: Cost = 7739.308594
# Iteration 479: Cost = 7736.223145
# Iteration 480: Cost = 7733.138184
# Iteration 481: Cost = 7730.055176
# Iteration 482: Cost = 7726.973633
# Iteration 483: Cost = 7723.892578
# Iteration 484: Cost = 7720.812500
# Iteration 485: Cost = 7717.734375
# Iteration 486: Cost = 7714.657227
# Iteration 487: Cost = 7711.582031
# Iteration 488: Cost = 7708.506836
# Iteration 489: Cost = 7705.434082
# Iteration 490: Cost = 7702.362305
# Iteration 491: Cost = 7699.291016
# Iteration 492: Cost = 7696.222168
# Iteration 493: Cost = 7693.153320
# Iteration 494: Cost = 7690.086426
# Iteration 495: Cost = 7687.020508
# Iteration 496: Cost = 7683.956543
# Iteration 497: Cost = 7680.892578
# Iteration 498: Cost = 7677.831055
# Iteration 499: Cost = 7674.770996
# Iteration 500: Cost = 7671.710938
# Iteration 501: Cost = 7668.652832
# Iteration 502: Cost = 7665.595215
# Iteration 503: Cost = 7662.539062
# Iteration 504: Cost = 7659.485352
# Iteration 505: Cost = 7656.431641
# Iteration 506: Cost = 7653.379883
# Iteration 507: Cost = 7650.328613
# Iteration 508: Cost = 7647.278809
# Iteration 509: Cost = 7644.230957
# Iteration 510: Cost = 7641.183594
# Iteration 511: Cost = 7638.137207
# Iteration 512: Cost = 7635.092773
# Iteration 513: Cost = 7632.049316
# Iteration 514: Cost = 7629.007812
# Iteration 515: Cost = 7625.966309
# Iteration 516: Cost = 7622.926270
# Iteration 517: Cost = 7619.887695
# Iteration 518: Cost = 7616.851074
# Iteration 519: Cost = 7613.814941
# Iteration 520: Cost = 7610.778809
# Iteration 521: Cost = 7607.747070
# Iteration 522: Cost = 7604.714355
# Iteration 523: Cost = 7601.683105
# Iteration 524: Cost = 7598.652832
# Iteration 525: Cost = 7595.624023
# Iteration 526: Cost = 7592.597168
# Iteration 527: Cost = 7589.570801
# Iteration 528: Cost = 7586.546387
# Iteration 529: Cost = 7583.521484
# Iteration 530: Cost = 7580.500000
# Iteration 531: Cost = 7577.478027
# Iteration 532: Cost = 7574.458984
# Iteration 533: Cost = 7571.439941
# Iteration 534: Cost = 7568.421387
# Iteration 535: Cost = 7565.405273
# Iteration 536: Cost = 7562.390137
# Iteration 537: Cost = 7559.376465
# Iteration 538: Cost = 7556.364746
# Iteration 539: Cost = 7553.352051
# Iteration 540: Cost = 7550.342285
# Iteration 541: Cost = 7547.332520
# Iteration 542: Cost = 7544.325195
# Iteration 543: Cost = 7541.318359
# Iteration 544: Cost = 7538.312500
# Iteration 545: Cost = 7535.308594
# Iteration 546: Cost = 7532.306152
# Iteration 547: Cost = 7529.303711
# Iteration 548: Cost = 7526.303711
# Iteration 549: Cost = 7523.304688
# Iteration 550: Cost = 7520.307129
# Iteration 551: Cost = 7517.309570
# Iteration 552: Cost = 7514.313477
# Iteration 553: Cost = 7511.318848
# Iteration 554: Cost = 7508.326172
# Iteration 555: Cost = 7505.333984
# Iteration 556: Cost = 7502.343750
# Iteration 557: Cost = 7499.354004
# Iteration 558: Cost = 7496.366211
# Iteration 559: Cost = 7493.378906
# Iteration 560: Cost = 7490.392578
# Iteration 561: Cost = 7487.407715
# Iteration 562: Cost = 7484.424805
# Iteration 563: Cost = 7481.442383
# Iteration 564: Cost = 7478.460449
# Iteration 565: Cost = 7475.481445
# Iteration 566: Cost = 7472.502441
# Iteration 567: Cost = 7469.524414
# Iteration 568: Cost = 7466.548828
# Iteration 569: Cost = 7463.574219
# Iteration 570: Cost = 7460.599609
# Iteration 571: Cost = 7457.627930
# Iteration 572: Cost = 7454.655762
# Iteration 573: Cost = 7451.686035
# Iteration 574: Cost = 7448.716797
# Iteration 575: Cost = 7445.748535
# Iteration 576: Cost = 7442.782227
# Iteration 577: Cost = 7439.817383
# Iteration 578: Cost = 7436.852539
# Iteration 579: Cost = 7433.889648
# Iteration 580: Cost = 7430.927734
# Iteration 581: Cost = 7427.967773
# Iteration 582: Cost = 7425.007812
# Iteration 583: Cost = 7422.050293
# Iteration 584: Cost = 7419.093262
# Iteration 585: Cost = 7416.137207
# Iteration 586: Cost = 7413.182129
# Iteration 587: Cost = 7410.228516
# Iteration 588: Cost = 7407.276855
# Iteration 589: Cost = 7404.326172
# Iteration 590: Cost = 7401.375977
# Iteration 591: Cost = 7398.427734
# Iteration 592: Cost = 7395.479980
# Iteration 593: Cost = 7392.534180
# Iteration 594: Cost = 7389.589355
# Iteration 595: Cost = 7386.645996
# Iteration 596: Cost = 7383.703125
# Iteration 597: Cost = 7380.761230
# Iteration 598: Cost = 7377.821289
# Iteration 599: Cost = 7374.882812
# Iteration 600: Cost = 7371.944824
# Iteration 601: Cost = 7369.007812
# Iteration 602: Cost = 7366.072754
# Iteration 603: Cost = 7363.138184
# Iteration 604: Cost = 7360.205566
# Iteration 605: Cost = 7357.273438
# Iteration 606: Cost = 7354.342773
# Iteration 607: Cost = 7351.412598
# Iteration 608: Cost = 7348.484375
# Iteration 609: Cost = 7345.557617
# Iteration 610: Cost = 7342.631836
# Iteration 611: Cost = 7339.707031
# Iteration 612: Cost = 7336.783691
# Iteration 613: Cost = 7333.860840
# Iteration 614: Cost = 7330.940430
# Iteration 615: Cost = 7328.020508
# Iteration 616: Cost = 7325.101562
# Iteration 617: Cost = 7322.183594
# Iteration 618: Cost = 7319.267090
# Iteration 619: Cost = 7316.352051
# Iteration 620: Cost = 7313.437988
# Iteration 621: Cost = 7310.525391
# Iteration 622: Cost = 7307.614258
# Iteration 623: Cost = 7304.703125
# Iteration 624: Cost = 7301.793457
# Iteration 625: Cost = 7298.884766
# Iteration 626: Cost = 7295.978027
# Iteration 627: Cost = 7293.071777
# Iteration 628: Cost = 7290.167969
# Iteration 629: Cost = 7287.264648
# Iteration 630: Cost = 7284.362305
# Iteration 631: Cost = 7281.461426
# Iteration 632: Cost = 7278.561523
# Iteration 633: Cost = 7275.662109
# Iteration 634: Cost = 7272.765625
# Iteration 635: Cost = 7269.868652
# Iteration 636: Cost = 7266.974121
# Iteration 637: Cost = 7264.079102
# Iteration 638: Cost = 7261.187012
# Iteration 639: Cost = 7258.295898
# Iteration 640: Cost = 7255.403809
# Iteration 641: Cost = 7252.515137
# Iteration 642: Cost = 7249.626953
# Iteration 643: Cost = 7246.740723
# Iteration 644: Cost = 7243.854004
# Iteration 645: Cost = 7240.969238
# Iteration 646: Cost = 7238.086426
# Iteration 647: Cost = 7235.203613
# Iteration 648: Cost = 7232.323242
# Iteration 649: Cost = 7229.442871
# Iteration 650: Cost = 7226.564453
# Iteration 651: Cost = 7223.686035
# Iteration 652: Cost = 7220.810059
# Iteration 653: Cost = 7217.934082
# Iteration 654: Cost = 7215.060547
# Iteration 655: Cost = 7212.187988
# Iteration 656: Cost = 7209.316406
# Iteration 657: Cost = 7206.444824
# Iteration 658: Cost = 7203.575684
# Iteration 659: Cost = 7200.708008
# Iteration 660: Cost = 7197.839844
# Iteration 661: Cost = 7194.974121
# Iteration 662: Cost = 7192.109375
# Iteration 663: Cost = 7189.246094
# Iteration 664: Cost = 7186.383789
# Iteration 665: Cost = 7183.522461
# Iteration 666: Cost = 7180.662109
# Iteration 667: Cost = 7177.803223
# Iteration 668: Cost = 7174.945312
# Iteration 669: Cost = 7172.087891
# Iteration 670: Cost = 7169.233398
# Iteration 671: Cost = 7166.378906
# Iteration 672: Cost = 7163.525391
# Iteration 673: Cost = 7160.673340
# Iteration 674: Cost = 7157.823242
# Iteration 675: Cost = 7154.972656
# Iteration 676: Cost = 7152.124512
# Iteration 677: Cost = 7149.276855
# Iteration 678: Cost = 7146.431152
# Iteration 679: Cost = 7143.585449
# Iteration 680: Cost = 7140.741211
# Iteration 681: Cost = 7137.898926
# Iteration 682: Cost = 7135.057617
# Iteration 683: Cost = 7132.216797
# Iteration 684: Cost = 7129.377441
# Iteration 685: Cost = 7126.539062
# Iteration 686: Cost = 7123.702148
# Iteration 687: Cost = 7120.867188
# Iteration 688: Cost = 7118.031738
# Iteration 689: Cost = 7115.198242
# Iteration 690: Cost = 7112.365234
# Iteration 691: Cost = 7109.534180
# Iteration 692: Cost = 7106.703613
# Iteration 693: Cost = 7103.875000
# Iteration 694: Cost = 7101.047852
# Iteration 695: Cost = 7098.220703
# Iteration 696: Cost = 7095.395020
# Iteration 697: Cost = 7092.570801
# Iteration 698: Cost = 7089.748047
# Iteration 699: Cost = 7086.925293
# Iteration 700: Cost = 7084.104004
# Iteration 701: Cost = 7081.285645
# Iteration 702: Cost = 7078.466309
# Iteration 703: Cost = 7075.647949
# Iteration 704: Cost = 7072.832520
# Iteration 705: Cost = 7070.017578
# Iteration 706: Cost = 7067.203125
# Iteration 707: Cost = 7064.390137
# Iteration 708: Cost = 7061.578125
# Iteration 709: Cost = 7058.767578
# Iteration 710: Cost = 7055.958008
# Iteration 711: Cost = 7053.149414
# Iteration 712: Cost = 7050.343262
# Iteration 713: Cost = 7047.536621
# Iteration 714: Cost = 7044.730957
# Iteration 715: Cost = 7041.927734
# Iteration 716: Cost = 7039.125488
# Iteration 717: Cost = 7036.323242
# Iteration 718: Cost = 7033.522949
# Iteration 719: Cost = 7030.723633
# Iteration 720: Cost = 7027.925293
# Iteration 721: Cost = 7025.129395
# Iteration 722: Cost = 7022.332520
# Iteration 723: Cost = 7019.537598
# Iteration 724: Cost = 7016.744629
# Iteration 725: Cost = 7013.951660
# Iteration 726: Cost = 7011.161621
# Iteration 727: Cost = 7008.371094
# Iteration 728: Cost = 7005.581543
# Iteration 729: Cost = 7002.793457
# Iteration 730: Cost = 7000.006348
# Iteration 731: Cost = 6997.221191
# Iteration 732: Cost = 6994.436523
# Iteration 733: Cost = 6991.652832
# Iteration 734: Cost = 6988.871582
# Iteration 735: Cost = 6986.090332
# Iteration 736: Cost = 6983.310059
# Iteration 737: Cost = 6980.531250
# Iteration 738: Cost = 6977.753418
# Iteration 739: Cost = 6974.976562
# Iteration 740: Cost = 6972.200684
# Iteration 741: Cost = 6969.427246
# Iteration 742: Cost = 6966.654297
# Iteration 743: Cost = 6963.881348
# Iteration 744: Cost = 6961.110352
# Iteration 745: Cost = 6958.340820
# Iteration 746: Cost = 6955.571777
# Iteration 747: Cost = 6952.803711
# Iteration 748: Cost = 6950.037598
# Iteration 749: Cost = 6947.271973
# Iteration 750: Cost = 6944.508789
# Iteration 751: Cost = 6941.744629
# Iteration 752: Cost = 6938.982910
# Iteration 753: Cost = 6936.222168
# Iteration 754: Cost = 6933.462402
# Iteration 755: Cost = 6930.703613
# Iteration 756: Cost = 6927.946289
# Iteration 757: Cost = 6925.190430
# Iteration 758: Cost = 6922.434082
# Iteration 759: Cost = 6919.679688
# Iteration 760: Cost = 6916.927246
# Iteration 761: Cost = 6914.174805
# Iteration 762: Cost = 6911.423828
# Iteration 763: Cost = 6908.674805
# Iteration 764: Cost = 6905.926270
# Iteration 765: Cost = 6903.178223
# Iteration 766: Cost = 6900.431641
# Iteration 767: Cost = 6897.687012
# Iteration 768: Cost = 6894.942871
# Iteration 769: Cost = 6892.199707
# Iteration 770: Cost = 6889.457520
# Iteration 771: Cost = 6886.717285
# Iteration 772: Cost = 6883.977539
# Iteration 773: Cost = 6881.238281
# Iteration 774: Cost = 6878.501465
# Iteration 775: Cost = 6875.765625
# Iteration 776: Cost = 6873.030273
# Iteration 777: Cost = 6870.295898
# Iteration 778: Cost = 6867.562988
# Iteration 779: Cost = 6864.831055
# Iteration 780: Cost = 6862.100586
# Iteration 781: Cost = 6859.371094
# Iteration 782: Cost = 6856.641602
# Iteration 783: Cost = 6853.914062
# Iteration 784: Cost = 6851.188477
# Iteration 785: Cost = 6848.462891
# Iteration 786: Cost = 6845.739258
# Iteration 787: Cost = 6843.015625
# Iteration 788: Cost = 6840.293457
# Iteration 789: Cost = 6837.572754
# Iteration 790: Cost = 6834.853516
# Iteration 791: Cost = 6832.134277
# Iteration 792: Cost = 6829.417480
# Iteration 793: Cost = 6826.699707
# Iteration 794: Cost = 6823.985352
# Iteration 795: Cost = 6821.271973
# Iteration 796: Cost = 6818.558105
# Iteration 797: Cost = 6815.846191
# Iteration 798: Cost = 6813.135254
# Iteration 799: Cost = 6810.424805
# Iteration 800: Cost = 6807.716797
# Iteration 801: Cost = 6805.009277
# Iteration 802: Cost = 6802.302246
# Iteration 803: Cost = 6799.596680
# Iteration 804: Cost = 6796.892578
# Iteration 805: Cost = 6794.190430
# Iteration 806: Cost = 6791.487793
# Iteration 807: Cost = 6788.787109
# Iteration 808: Cost = 6786.086426
# Iteration 809: Cost = 6783.387695
# Iteration 810: Cost = 6780.690430
# Iteration 811: Cost = 6777.993652
# Iteration 812: Cost = 6775.297363
# Iteration 813: Cost = 6772.603027
# Iteration 814: Cost = 6769.909668
# Iteration 815: Cost = 6767.217285
# Iteration 816: Cost = 6764.526367
# Iteration 817: Cost = 6761.836426
# Iteration 818: Cost = 6759.146973
# Iteration 819: Cost = 6756.458984
# Iteration 820: Cost = 6753.772461
# Iteration 821: Cost = 6751.086914
# Iteration 822: Cost = 6748.402832
# Iteration 823: Cost = 6745.719238
# Iteration 824: Cost = 6743.036621
# Iteration 825: Cost = 6740.354980
# Iteration 826: Cost = 6737.674805
# Iteration 827: Cost = 6734.995117
# Iteration 828: Cost = 6732.318359
# Iteration 829: Cost = 6729.639648
# Iteration 830: Cost = 6726.964844
# Iteration 831: Cost = 6724.289551
# Iteration 832: Cost = 6721.616699
# Iteration 833: Cost = 6718.943848
# Iteration 834: Cost = 6716.271973
# Iteration 835: Cost = 6713.601562
# Iteration 836: Cost = 6710.931152
# Iteration 837: Cost = 6708.263672
# Iteration 838: Cost = 6705.595703
# Iteration 839: Cost = 6702.930176
# Iteration 840: Cost = 6700.265137
# Iteration 841: Cost = 6697.601562
# Iteration 842: Cost = 6694.937988
# Iteration 843: Cost = 6692.276367
# Iteration 844: Cost = 6689.615723
# Iteration 845: Cost = 6686.956055
# Iteration 846: Cost = 6684.296875
# Iteration 847: Cost = 6681.639648
# Iteration 848: Cost = 6678.983887
# Iteration 849: Cost = 6676.327637
# Iteration 850: Cost = 6673.673828
# Iteration 851: Cost = 6671.020508
# Iteration 852: Cost = 6668.368652
# Iteration 853: Cost = 6665.717285
# Iteration 854: Cost = 6663.067383
# Iteration 855: Cost = 6660.418457
# Iteration 856: Cost = 6657.770508
# Iteration 857: Cost = 6655.124023
# Iteration 858: Cost = 6652.478027
# Iteration 859: Cost = 6649.833496
# Iteration 860: Cost = 6647.190430
# Iteration 861: Cost = 6644.547852
# Iteration 862: Cost = 6641.906250
# Iteration 863: Cost = 6639.265625
# Iteration 864: Cost = 6636.626465
# Iteration 865: Cost = 6633.988770
# Iteration 866: Cost = 6631.351562
# Iteration 867: Cost = 6628.715332
# Iteration 868: Cost = 6626.080566
# Iteration 869: Cost = 6623.446777
# Iteration 870: Cost = 6620.813965
# Iteration 871: Cost = 6618.182129
# Iteration 872: Cost = 6615.551758
# Iteration 873: Cost = 6612.922363
# Iteration 874: Cost = 6610.293457
# Iteration 875: Cost = 6607.665527
# Iteration 876: Cost = 6605.039551
# Iteration 877: Cost = 6602.414062
# Iteration 878: Cost = 6599.790039
# Iteration 879: Cost = 6597.166504
# Iteration 880: Cost = 6594.544434
# Iteration 881: Cost = 6591.922852
# Iteration 882: Cost = 6589.303223
# Iteration 883: Cost = 6586.684082
# Iteration 884: Cost = 6584.066406
# Iteration 885: Cost = 6581.449219
# Iteration 886: Cost = 6578.834473
# Iteration 887: Cost = 6576.219238
# Iteration 888: Cost = 6573.605469
# Iteration 889: Cost = 6570.992676
# Iteration 890: Cost = 6568.381348
# Iteration 891: Cost = 6565.770996
# Iteration 892: Cost = 6563.161621
# Iteration 893: Cost = 6560.553223
# Iteration 894: Cost = 6557.946289
# Iteration 895: Cost = 6555.339844
# Iteration 896: Cost = 6552.734863
# Iteration 897: Cost = 6550.130371
# Iteration 898: Cost = 6547.526855
# Iteration 899: Cost = 6544.925293
# Iteration 900: Cost = 6542.324707
# Iteration 901: Cost = 6539.724609
# Iteration 902: Cost = 6537.125488
# Iteration 903: Cost = 6534.527832
# Iteration 904: Cost = 6531.931152
# Iteration 905: Cost = 6529.335938
# Iteration 906: Cost = 6526.741211
# Iteration 907: Cost = 6524.147461
# Iteration 908: Cost = 6521.555176
# Iteration 909: Cost = 6518.963379
# Iteration 910: Cost = 6516.373047
# Iteration 911: Cost = 6513.783691
# Iteration 912: Cost = 6511.195312
# Iteration 913: Cost = 6508.607910
# Iteration 914: Cost = 6506.021973
# Iteration 915: Cost = 6503.436523
# Iteration 916: Cost = 6500.852539
# Iteration 917: Cost = 6498.269531
# Iteration 918: Cost = 6495.687988
# Iteration 919: Cost = 6493.106445
# Iteration 920: Cost = 6490.526855
# Iteration 921: Cost = 6487.947754
# Iteration 922: Cost = 6485.369629
# Iteration 923: Cost = 6482.792969
# Iteration 924: Cost = 6480.217285
# Iteration 925: Cost = 6477.643066
# Iteration 926: Cost = 6475.069336
# Iteration 927: Cost = 6472.496582
# Iteration 928: Cost = 6469.924805
# Iteration 929: Cost = 6467.354492
# Iteration 930: Cost = 6464.785645
# Iteration 931: Cost = 6462.216797
# Iteration 932: Cost = 6459.649414
# Iteration 933: Cost = 6457.083008
# Iteration 934: Cost = 6454.518066
# Iteration 935: Cost = 6451.953613
# Iteration 936: Cost = 6449.390137
# Iteration 937: Cost = 6446.827637
# Iteration 938: Cost = 6444.267090
# Iteration 939: Cost = 6441.707031
# Iteration 940: Cost = 6439.147949
# Iteration 941: Cost = 6436.589844
# Iteration 942: Cost = 6434.033203
# Iteration 943: Cost = 6431.477051
# Iteration 944: Cost = 6428.922363
# Iteration 945: Cost = 6426.368652
# Iteration 946: Cost = 6423.815430
# Iteration 947: Cost = 6421.263672
# Iteration 948: Cost = 6418.712402
# Iteration 949: Cost = 6416.163086
# Iteration 950: Cost = 6413.614746
# Iteration 951: Cost = 6411.066895
# Iteration 952: Cost = 6408.520020
# Iteration 953: Cost = 6405.974121
# Iteration 954: Cost = 6403.430176
# Iteration 955: Cost = 6400.886230
# Iteration 956: Cost = 6398.343750
# Iteration 957: Cost = 6395.802734
# Iteration 958: Cost = 6393.262207
# Iteration 959: Cost = 6390.723145
# Iteration 960: Cost = 6388.184570
# Iteration 961: Cost = 6385.646973
# Iteration 962: Cost = 6383.110840
# Iteration 963: Cost = 6380.575684
# Iteration 964: Cost = 6378.041504
# Iteration 965: Cost = 6375.508301
# Iteration 966: Cost = 6372.976074
# Iteration 967: Cost = 6370.444824
# Iteration 968: Cost = 6367.915039
# Iteration 969: Cost = 6365.385254
# Iteration 970: Cost = 6362.857910
# Iteration 971: Cost = 6360.330566
# Iteration 972: Cost = 6357.804688
# Iteration 973: Cost = 6355.279785
# Iteration 974: Cost = 6352.755859
# Iteration 975: Cost = 6350.232422
# Iteration 976: Cost = 6347.710449
# Iteration 977: Cost = 6345.189941
# Iteration 978: Cost = 6342.669922
# Iteration 979: Cost = 6340.150879
# Iteration 980: Cost = 6337.633301
# Iteration 981: Cost = 6335.116699
# Iteration 982: Cost = 6332.600586
# Iteration 983: Cost = 6330.086426
# Iteration 984: Cost = 6327.571777
# Iteration 985: Cost = 6325.060059
# Iteration 986: Cost = 6322.547852
# Iteration 987: Cost = 6320.037598
# Iteration 988: Cost = 6317.527832
# Iteration 989: Cost = 6315.019043
# Iteration 990: Cost = 6312.511230
# Iteration 991: Cost = 6310.004883
# Iteration 992: Cost = 6307.499023
# Iteration 993: Cost = 6304.994141
# Iteration 994: Cost = 6302.491211
# Iteration 995: Cost = 6299.988281
# Iteration 996: Cost = 6297.486816
# Iteration 997: Cost = 6294.986328
# Iteration 998: Cost = 6292.486816
# Iteration 999: Cost = 6289.987793
# Iteration 1000: Cost = 6287.490723
# Iteration 10001: Cost = 293.994232
# Iteration 20001: Cost = 133.044525
# Iteration 30001: Cost = 125.887146
# Iteration 40001: Cost = 121.577072
# iteration stopped at step:  49999
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
