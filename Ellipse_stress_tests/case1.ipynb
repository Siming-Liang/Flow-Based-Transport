# %% [markdown]
# # Case1 moderate anisotropy with partial observation

# %% [markdown]
# ## Pacakages and Functions

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))   # the git/ folder, where utility.py lives
from utility import *  
import torch
import numpy as np
from inc_ensf import EnSF
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import math
from scipy.linalg import qr
from matplotlib.collections import LineCollection
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator

use_this = 'cuda:7'

# %%
def cov_generate(n,lambda_1,lambda_rest):
    # n: dimension
    # 1. Direction of the line (e.g., all ones)
    v = np.ones(n)
    v /= np.linalg.norm(v)  # Normalize

    # 2. Create an orthonormal basis using QR decomposition
    # Stack v with random orthogonal vectors
    random_matrix = np.random.randn(n, n)
    random_matrix[:, 0] = v  # Set first column as v

    # QR gives orthonormal basis
    Q, _ = qr(random_matrix)  # Q is orthonormal, v is Q[:, 0]

    Lambda = np.diag([lambda_1] + [lambda_rest] * (n - 1))

    # 4. Build covariance matrix
    Sigma = Q @ Lambda @ Q.T  # Q * diag * Q^T
    Sigma += 1e-3 * np.eye(Sigma.shape[0])  # add jitter
    return Sigma

# %% [markdown]
# ## generate sample

# %%
#test question
N_dim=10
ensemble_size = 10000
main_var = 10
other_var = 1.00
# generate samples
torch.manual_seed(100)
np.random.seed(8)
mean = torch.zeros(N_dim, device= use_this, dtype=torch.float32)
covariance_matrix = torch.tensor(cov_generate(N_dim,main_var,other_var), device= use_this, dtype=torch.float32)
mvn = torch.distributions.MultivariateNormal(mean, covariance_matrix)
test_sample = mvn.sample(sample_shape=(ensemble_size,))
test_sample[0] = 0
# print(test_sample.mean(dim=0),"\n",test_sample.T.cov(), "\n",torch.linalg.cond(covariance_matrix))

# %%
def to_numpy(a):
    return a.detach().cpu().numpy() if hasattr(a, "detach") else np.asarray(a)

test_all = to_numpy(test_sample)
# # =========================
# # 1) Build "result" samples by conditioning on x[d0] = x0_obs
# # =========================


Sigma = covariance_matrix.detach().cpu().numpy() if hasattr(covariance_matrix, "detach") else np.asarray(covariance_matrix)
n = Sigma.shape[0]

d0 = 0          # observed dimension
y  = 2      # observation value. 
sigma_obs = 0.1   

R = sigma_obs**2  
K = Sigma[:, d0] / (Sigma[d0, d0] + R)
mu_a = K * y
# Posterior covariance (n,n)
Sigma_a = Sigma - np.outer(Sigma[:, d0], Sigma[d0, :]) / (Sigma[d0, d0] + R)
# Sample posterior
rng = np.random.default_rng(123)
result_all = rng.multivariate_normal(mu_a, Sigma_a, size=ensemble_size)


for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        # choose 2D projection dims
        d0, d1 = dim_plot[0], dim_plot[1]
        # 2D arrays for plotting
        test   = test_all[:, [d0, d1]]
        result = result_all[:, [d0, d1]]

        # means/covs in 2D
        mean_test   = test.mean(axis=0)
        cov_test    = np.cov(test.T)

        mean_result = result.mean(axis=0)
        cov_result  = np.cov(result.T)
        ref_loc = mean_result.copy()
        # =========================
        # 2) Ellipse helper (yours)
        # =========================
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(np.maximum(eigvals, 0))
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)
            return ellipse

        # =========================
        # 3) Plot: prior vs post + path + ellipses
        # =========================
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)

        # scatter (keep s tiny; enlarge legend markers separately)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #     manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])
        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post (cond)", s=0.04, color="tab:orange")
        
        # covariance ellipses
        plot_cov_ellipse(cov_test,   mean_test,   ax, edgecolor="tab:blue", facecolor="none", linewidth=0.1,
                        label="Cov ellipse prior")
        plot_cov_ellipse(cov_result, mean_result, ax, edgecolor="tab:orange",  facecolor="none", linewidth=0.1,
                        label="Cov ellipse post")
        
        ax.axis("equal")

        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.xaxis.set_major_locator(MultipleLocator(2))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(2))   # y-axis tick every 5

        ax.tick_params(axis='both', which='major', labelsize=24)
        ax.grid(alpha = 0.3)
        #ax.legend(markerscale=25)  # enlarge legend markers only
        plt.tight_layout()
        sigma_str = "mix"#f"{sigma_obs:g}".replace(".", "p")
        plt.show()
        plt.close()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## EnSF

# %% [markdown]
# ### ensemble-mean paths

# %%
testensf = EnSF(n_dim = N_dim, ensemble_size = ensemble_size ,eps_alpha=0.01, eps_beta= 0.00, device= use_this ,obs_sigma = 0.1, euler_steps = 1)
ensf_iteration = 100
result1 = testensf.RSDE_incremental(obs=2, x0=0, x_prior=test_sample.clone(), time_steps=ensf_iteration, ens_cov=covariance_matrix/0.3, sparse_idx=[0],cov_scale = 0.3, tau_scale = 1) 

#path mean
x = (result1).cpu().detach().numpy()
for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        rotated_test_sample = test_sample[:,dim_plot] 
        d0, d1 = dim_plot[0], dim_plot[1]
        ref_loc = result_all[:, [d0, d1]].mean(axis=0)
        test = rotated_test_sample.cpu().numpy()  #rotated_test_sample
        result = ((result1[:,dim_plot,-1])) .cpu().numpy() #+test_sample[:,dim_plot]
        # Define the 2D covariance matrix
        cov_test = np.cov(test.T)
        cov_result = np.cov(result.T)

        # Mean of the distribution (center of the ellipse)
        mean_test = test.mean(axis = 0)
        mean_result = result.mean(axis = 0)
        # Generate samples from the multivariate normal distribution

        # Plot the samples
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #   manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])

        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post", s=0.04, color = "tab:orange")

        # Function to draw the covariance ellipse
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(eigvals)
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)

        # Draw the ellipse
        plot_cov_ellipse(cov_test,mean_test, ax, edgecolor='tab:blue', facecolor='none', linewidth=0.1, label='Covariance Ellipse Prior')
        plot_cov_ellipse(cov_result,mean_result, ax, edgecolor='tab:orange', facecolor='none', linewidth=0.1, label='Covariance Ellipse post')
        #mark the reference point
        ensf_path = x[:,dim_plot,:]
        px, py = ensf_path[:,0].mean(axis=0),ensf_path[:,1].mean(axis=0)
        plt.plot(px, py,'--',linewidth=1,color = "black", label='EnSF')

        def arrow_at(ax, x, y, idx, color='black', size=58, lw=1, back=50, tail_pt=0.5):
            """Open '>' arrowhead at point idx, oriented along the local path direction."""
            j = max(idx - back, 0)
            d = np.array([x[idx] - x[j], y[idx] - y[j]])
            d /= np.linalg.norm(d) + 1e-12
            ax.annotate('', xy=(x[idx], y[idx]),
                        xytext=(-tail_pt * d[0], -tail_pt * d[1]), textcoords='offset points',
                        arrowprops=dict(arrowstyle='->', color=color, mutation_scale=size,
                                        lw=lw, shrinkA=0, shrinkB=0), zorder=6)


        ax.scatter(mean_test[0], mean_test[1], marker='^', alpha=1, color ="tab:blue" ,label="reference", s=400)
        ax.scatter(mean_result[0], mean_result[1], marker='s',alpha=1, color ="black" ,label="reference", s=200)
        ax.axis('equal')

        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.xaxis.set_major_locator(MultipleLocator(2))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(2))   # y-axis tick every 5
        ax.tick_params(axis='both', which='major', labelsize=24)

        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
        plt.close()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## 3DEnVar

# %% [markdown]
# ### ensemble-mean paths

# %%
#sparse obs
plot_endpont = -1
H = lambda x: x
obs = torch.tensor((2))
# Create EnVar instance
# replace with __all__ = ['EnVar3D', 'CVT3dEnVar', 'CVT3dEnVarPerturbedObs', 'EnVar3DPerturbedObs']
envar = EnVar3D(H=H, y_obs=obs, B = covariance_matrix, R=torch.eye(N_dim)*0.1, Xb= test_sample.clone(),obs_idx=[0], learning_rate=0.1, max_iterations=1000, convergence_threshold=1e-6, device=use_this)
# Run assimilation
x_analysis,nan_idx, x_path = envar.run()

#path mean
x = (x_path).cpu().detach().numpy()
for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        rotated_test_sample = test_sample[:,dim_plot] 
        d0, d1 = dim_plot[0], dim_plot[1]
        ref_loc = result_all[:, [d0, d1]].mean(axis=0)
        test = rotated_test_sample.cpu().numpy()  #rotated_test_sample
        result = x[plot_endpont][:, dim_plot]
        # Define the 2D covariance matrix
        cov_test = np.cov(test.T)
        cov_result = np.cov(result.T)

        # Mean of the distribution (center of the ellipse)
        mean_test = test.mean(axis = 0)
        mean_result = result.mean(axis = 0)
        # Generate samples from the multivariate normal distribution

        # Plot the samples
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #   manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])

        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post", s=0.04, color = "tab:orange")

        # Function to draw the covariance ellipse
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(eigvals)
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)

        # Draw the ellipse
        plot_cov_ellipse(cov_test,mean_test, ax, edgecolor='tab:blue', facecolor='none', linewidth=0.1, label='Covariance Ellipse Prior')
        plot_cov_ellipse(cov_result,mean_result, ax, edgecolor='tab:orange', facecolor='none', linewidth=0.1, label='Covariance Ellipse post')
        #mark the reference point
        ensf_path = x[:plot_endpont,:,dim_plot].mean(axis=1)
        px, py = ensf_path[:, 0], ensf_path[:, 1]
        plt.plot(px, py,'--',linewidth=1,color = "black", label='EnSF')

        def arrow_at(ax, x, y, idx, color='black', size=58, lw=1, back=50, tail_pt=0.5):
            """Open '>' arrowhead at point idx, oriented along the local path direction."""
            j = max(idx - back, 0)
            d = np.array([x[idx] - x[j], y[idx] - y[j]])
            d /= np.linalg.norm(d) + 1e-12
            ax.annotate('', xy=(x[idx], y[idx]),
                        xytext=(-tail_pt * d[0], -tail_pt * d[1]), textcoords='offset points',
                        arrowprops=dict(arrowstyle='->', color=color, mutation_scale=size,
                                        lw=lw, shrinkA=0, shrinkB=0), zorder=6)


        ax.scatter(mean_test[0], mean_test[1], marker='^', alpha=1, color ="tab:blue" ,label="reference", s=400)
        ax.scatter(mean_result[0], mean_result[1], marker='s',alpha=1, color ="black" ,label="reference", s=200)
        ax.axis('equal')

        ax.set_xlim(-4, 4)
        ax.set_ylim(-4, 4)
        ax.xaxis.set_major_locator(MultipleLocator(2))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(2))   # y-axis tick every 5
        ax.tick_params(axis='both', which='major', labelsize=24)

        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
        plt.close()
# Out:
# Iteration 1: Cost = 29.516335
# Iteration 2: Cost = 2.683330
# Iteration 3: Cost = 2.422936
# Iteration 4: Cost = 2.386725
# Iteration 5: Cost = 2.353629
# Iteration 6: Cost = 2.321749
# Iteration 7: Cost = 2.291027
# Iteration 8: Cost = 2.261419
# Iteration 9: Cost = 2.232885
# Iteration 10: Cost = 2.205387
# Iteration 11: Cost = 2.178886
# Iteration 12: Cost = 2.153347
# Iteration 13: Cost = 2.128736
# Iteration 14: Cost = 2.105017
# Iteration 15: Cost = 2.082158
# Iteration 16: Cost = 2.060130
# Iteration 17: Cost = 2.038900
# Iteration 18: Cost = 2.018441
# Iteration 19: Cost = 1.998724
# Iteration 20: Cost = 1.979723
# Iteration 21: Cost = 1.961411
# Iteration 22: Cost = 1.943764
# Iteration 23: Cost = 1.926757
# Iteration 24: Cost = 1.910367
# Iteration 25: Cost = 1.894572
# Iteration 26: Cost = 1.879350
# Iteration 27: Cost = 1.864680
# Iteration 28: Cost = 1.850543
# Iteration 29: Cost = 1.836918
# Iteration 30: Cost = 1.823789
# Iteration 31: Cost = 1.811135
# Iteration 32: Cost = 1.798941
# Iteration 33: Cost = 1.787189
# Iteration 34: Cost = 1.775864
# Iteration 35: Cost = 1.764949
# Iteration 36: Cost = 1.754431
# Iteration 37: Cost = 1.744294
# Iteration 38: Cost = 1.734525
# Iteration 39: Cost = 1.725111
# Iteration 40: Cost = 1.716038
# Iteration 41: Cost = 1.707294
# Iteration 42: Cost = 1.698868
# Iteration 43: Cost = 1.690748
# Iteration 44: Cost = 1.682922
# Iteration 45: Cost = 1.675380
# Iteration 46: Cost = 1.668111
# Iteration 47: Cost = 1.661107
# Iteration 48: Cost = 1.654357
# Iteration 49: Cost = 1.647851
# Iteration 50: Cost = 1.641582
# Iteration 51: Cost = 1.635540
# Iteration 52: Cost = 1.629718
# Iteration 53: Cost = 1.624106
# Iteration 54: Cost = 1.618698
# Iteration 55: Cost = 1.613487
# Iteration 56: Cost = 1.608465
# Iteration 57: Cost = 1.603625
# Iteration 58: Cost = 1.598960
# Iteration 59: Cost = 1.594465
# Iteration 60: Cost = 1.590133
# Iteration 61: Cost = 1.585958
# Iteration 62: Cost = 1.581935
# Iteration 63: Cost = 1.578057
# Iteration 64: Cost = 1.574320
# Iteration 65: Cost = 1.570719
# Iteration 66: Cost = 1.567249
# Iteration 67: Cost = 1.563904
# Iteration 68: Cost = 1.560681
# Iteration 69: Cost = 1.557575
# Iteration 70: Cost = 1.554581
# Iteration 71: Cost = 1.551696
# Iteration 72: Cost = 1.548916
# Iteration 73: Cost = 1.546237
# Iteration 74: Cost = 1.543655
# Iteration 75: Cost = 1.541167
# Iteration 76: Cost = 1.538768
# Iteration 77: Cost = 1.536457
# Iteration 78: Cost = 1.534230
# Iteration 79: Cost = 1.532084
# Iteration 80: Cost = 1.530015
# Iteration 81: Cost = 1.528022
# Iteration 82: Cost = 1.526101
# Iteration 83: Cost = 1.524249
# Iteration 84: Cost = 1.522465
# Iteration 85: Cost = 1.520746
# Iteration 86: Cost = 1.519089
# Iteration 87: Cost = 1.517492
# Iteration 88: Cost = 1.515953
# Iteration 89: Cost = 1.514469
# Iteration 90: Cost = 1.513040
# Iteration 91: Cost = 1.511663
# Iteration 92: Cost = 1.510335
# Iteration 93: Cost = 1.509056
# Iteration 94: Cost = 1.507823
# Iteration 95: Cost = 1.506635
# Iteration 96: Cost = 1.505490
# Iteration 97: Cost = 1.504386
# Iteration 98: Cost = 1.503323
# Iteration 99: Cost = 1.502298
# Iteration 100: Cost = 1.501310
# Iteration 101: Cost = 1.500358
# Iteration 102: Cost = 1.499441
# Iteration 103: Cost = 1.498557
# Iteration 104: Cost = 1.497705
# Iteration 105: Cost = 1.496884
# Iteration 106: Cost = 1.496093
# Iteration 107: Cost = 1.495330
# Iteration 108: Cost = 1.494596
# Iteration 109: Cost = 1.493887
# Iteration 110: Cost = 1.493205
# Iteration 111: Cost = 1.492547
# Iteration 112: Cost = 1.491913
# Iteration 113: Cost = 1.491302
# Iteration 114: Cost = 1.490714
# Iteration 115: Cost = 1.490146
# Iteration 116: Cost = 1.489600
# Iteration 117: Cost = 1.489073
# Iteration 118: Cost = 1.488565
# Iteration 119: Cost = 1.488075
# Iteration 120: Cost = 1.487604
# Iteration 121: Cost = 1.487149
# Iteration 122: Cost = 1.486712
# Iteration 123: Cost = 1.486289
# Iteration 124: Cost = 1.485883
# Iteration 125: Cost = 1.485491
# Iteration 126: Cost = 1.485113
# Iteration 127: Cost = 1.484749
# Iteration 128: Cost = 1.484398
# Iteration 129: Cost = 1.484060
# Iteration 130: Cost = 1.483734
# Iteration 131: Cost = 1.483420
# Iteration 132: Cost = 1.483117
# Iteration 133: Cost = 1.482825
# Iteration 134: Cost = 1.482544
# Iteration 135: Cost = 1.482273
# Iteration 136: Cost = 1.482012
# Iteration 137: Cost = 1.481761
# Iteration 138: Cost = 1.481518
# Iteration 139: Cost = 1.481285
# Iteration 140: Cost = 1.481060
# Iteration 141: Cost = 1.480842
# Iteration 142: Cost = 1.480633
# Iteration 143: Cost = 1.480432
# Iteration 144: Cost = 1.480238
# Iteration 145: Cost = 1.480050
# Iteration 146: Cost = 1.479870
# Iteration 147: Cost = 1.479696
# Iteration 148: Cost = 1.479529
# Iteration 149: Cost = 1.479367
# Iteration 150: Cost = 1.479211
# Iteration 151: Cost = 1.479062
# Iteration 152: Cost = 1.478917
# Iteration 153: Cost = 1.478778
# Iteration 154: Cost = 1.478644
# Iteration 155: Cost = 1.478514
# Iteration 156: Cost = 1.478390
# Iteration 157: Cost = 1.478269
# Iteration 158: Cost = 1.478154
# Iteration 159: Cost = 1.478042
# Iteration 160: Cost = 1.477934
# Iteration 161: Cost = 1.477831
# Iteration 162: Cost = 1.477731
# Iteration 163: Cost = 1.477635
# Iteration 164: Cost = 1.477542
# Iteration 165: Cost = 1.477453
# Iteration 166: Cost = 1.477367
# Iteration 167: Cost = 1.477284
# Iteration 168: Cost = 1.477204
# Iteration 169: Cost = 1.477126
# Iteration 170: Cost = 1.477052
# Iteration 171: Cost = 1.476981
# Iteration 172: Cost = 1.476912
# Iteration 173: Cost = 1.476845
# Iteration 174: Cost = 1.476781
# Iteration 175: Cost = 1.476719
# Iteration 176: Cost = 1.476660
# Iteration 177: Cost = 1.476602
# Iteration 178: Cost = 1.476547
# Iteration 179: Cost = 1.476494
# Iteration 180: Cost = 1.476443
# Iteration 181: Cost = 1.476393
# Iteration 182: Cost = 1.476345
# Iteration 183: Cost = 1.476300
# Iteration 184: Cost = 1.476255
# Iteration 185: Cost = 1.476213
# Iteration 186: Cost = 1.476171
# Iteration 187: Cost = 1.476132
# Iteration 188: Cost = 1.476094
# Iteration 189: Cost = 1.476057
# Iteration 190: Cost = 1.476021
# Iteration 191: Cost = 1.475987
# Iteration 192: Cost = 1.475954
# Iteration 193: Cost = 1.475922
# Iteration 194: Cost = 1.475892
# Iteration 195: Cost = 1.475862
# Iteration 196: Cost = 1.475834
# Iteration 197: Cost = 1.475806
# Iteration 198: Cost = 1.475780
# Iteration 199: Cost = 1.475755
# Iteration 200: Cost = 1.475730
# Iteration 201: Cost = 1.475706
# Iteration 202: Cost = 1.475684
# Iteration 203: Cost = 1.475662
# Iteration 204: Cost = 1.475641
# Iteration 205: Cost = 1.475620
# Iteration 206: Cost = 1.475601
# Iteration 207: Cost = 1.475582
# Iteration 208: Cost = 1.475563
# Iteration 209: Cost = 1.475546
# Iteration 210: Cost = 1.475529
# Iteration 211: Cost = 1.475513
# Iteration 212: Cost = 1.475497
# Iteration 213: Cost = 1.475482
# Iteration 214: Cost = 1.475467
# Iteration 215: Cost = 1.475453
# Iteration 216: Cost = 1.475439
# Iteration 217: Cost = 1.475426
# Iteration 218: Cost = 1.475414
# Iteration 219: Cost = 1.475402
# Iteration 220: Cost = 1.475390
# Iteration 221: Cost = 1.475379
# Iteration 222: Cost = 1.475368
# Iteration 223: Cost = 1.475357
# Iteration 224: Cost = 1.475347
# Iteration 225: Cost = 1.475338
# Iteration 226: Cost = 1.475328
# Iteration 227: Cost = 1.475319
# Iteration 228: Cost = 1.475310
# Iteration 229: Cost = 1.475302
# Iteration 230: Cost = 1.475294
# Iteration 231: Cost = 1.475286
# Iteration 232: Cost = 1.475279
# Iteration 233: Cost = 1.475271
# Iteration 234: Cost = 1.475264
# Iteration 235: Cost = 1.475258
# Iteration 236: Cost = 1.475251
# Iteration 237: Cost = 1.475245
# Iteration 238: Cost = 1.475239
# Iteration 239: Cost = 1.475233
# Iteration 240: Cost = 1.475227
# Iteration 241: Cost = 1.475222
# Iteration 242: Cost = 1.475217
# Iteration 243: Cost = 1.475212
# Iteration 244: Cost = 1.475207
# Iteration 245: Cost = 1.475202
# Iteration 246: Cost = 1.475198
# Iteration 247: Cost = 1.475194
# Iteration 248: Cost = 1.475189
# Iteration 249: Cost = 1.475186
# Iteration 250: Cost = 1.475182
# Iteration 251: Cost = 1.475178
# Iteration 252: Cost = 1.475174
# Iteration 253: Cost = 1.475171
# Iteration 254: Cost = 1.475168
# Iteration 255: Cost = 1.475164
# Iteration 256: Cost = 1.475161
# Iteration 257: Cost = 1.475158
# Iteration 258: Cost = 1.475155
# Iteration 259: Cost = 1.475153
# Iteration 260: Cost = 1.475150
# Iteration 261: Cost = 1.475147
# Iteration 262: Cost = 1.475145
# Iteration 263: Cost = 1.475143
# Iteration 264: Cost = 1.475140
# Iteration 265: Cost = 1.475138
# Iteration 266: Cost = 1.475136
# Iteration 267: Cost = 1.475134
# Iteration 268: Cost = 1.475132
# Iteration 269: Cost = 1.475130
# Iteration 270: Cost = 1.475128
# Iteration 271: Cost = 1.475126
# Iteration 272: Cost = 1.475125
# Iteration 273: Cost = 1.475123
# Iteration 274: Cost = 1.475121
# Iteration 275: Cost = 1.475120
# Iteration 276: Cost = 1.475118
# Iteration 277: Cost = 1.475117
# Iteration 278: Cost = 1.475116
# Iteration 279: Cost = 1.475114
# Iteration 280: Cost = 1.475113
# Iteration 281: Cost = 1.475112
# Iteration 282: Cost = 1.475111
# Iteration 283: Cost = 1.475109
# Iteration 284: Cost = 1.475108
# Iteration 285: Cost = 1.475107
# Iteration 286: Cost = 1.475106
# Convergence reached.
# iteration stopped at step:  285
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
