# %% [markdown]
# # Case2 extreme anisotropy with full observation

# %% [markdown]
# ## Pacakages and Functions

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))   # the git/ folder, where utility.py lives
from utility import *  
import torch
import numpy as np
from inc_ensf import EnSF
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import math
from scipy.linalg import qr
from matplotlib.collections import LineCollection
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator

use_this = 'cuda:7'

# %%
def cov_generate(n,lambda_1):
    # n: dimension
    # 1. Direction of the line (e.g., all ones)
    v = np.ones(n)
    v /= np.linalg.norm(v)  # Normalize

    # 2. Create an orthonormal basis using QR decomposition
    # Stack v with random orthogonal vectors
    random_matrix = np.random.randn(n, n)
    random_matrix[:, 0] = v  # Set first column as v

    # QR gives orthonormal basis
    Q, _ = qr(random_matrix)  # Q is orthonormal, v is Q[:, 0]
    Lambda = np.diag([lambda_1 * 10**(-i) for i in range(n)]) 

    # 4. Build covariance matrix
    Sigma = Q @ Lambda @ Q.T  # Q * diag * Q^T
    Sigma += 1e-3 * np.eye(Sigma.shape[0])  # add jitter
    return Sigma

# %% [markdown]
# ## generate sample

# %%
#test question
N_dim=10
ensemble_size = 10000
main_var = 1000000
# generate samples
torch.manual_seed(100)
np.random.seed(8)
mean = torch.zeros(N_dim, device= use_this, dtype=torch.float32)
covariance_matrix = torch.tensor(cov_generate(N_dim,main_var), device= use_this, dtype=torch.float32)
mvn = torch.distributions.MultivariateNormal(mean, covariance_matrix)
test_sample = mvn.sample(sample_shape=(ensemble_size,))
test_sample[0] = 0
# print(test_sample.mean(dim=0),"\n",test_sample.T.cov(), "\n",torch.linalg.cond(covariance_matrix))

# %%
def to_numpy(a):
    return a.detach().cpu().numpy() if hasattr(a, "detach") else np.asarray(a)

test_all = to_numpy(test_sample)
# # =========================
# # 1) Build "result" samples by conditioning on x[d0] = x0_obs
# # =========================


Sigma = covariance_matrix.detach().cpu().numpy() if hasattr(covariance_matrix, "detach") else np.asarray(covariance_matrix)
n = Sigma.shape[0]

y = 600.0 * np.ones(n)          # all 10 dims observed, all equal 150
sigma_obs = 50.0
R = sigma_obs**2
I = np.eye(n)

A = Sigma + R * I               # (n,n)

# Posterior mean
mu_a = Sigma @ np.linalg.solve(A, y)

# Posterior covariance
Sigma_a = Sigma - Sigma @ np.linalg.solve(A, Sigma)

# Sample posterior
rng = np.random.default_rng(123)
result_all = rng.multivariate_normal(mu_a, Sigma_a, size=ensemble_size)

for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        # choose 2D projection dims
        d0, d1 = dim_plot[0], dim_plot[1]
        # 2D arrays for plotting
        test   = test_all[:, [d0, d1]]
        result = result_all[:, [d0, d1]]

        # means/covs in 2D
        mean_test   = test.mean(axis=0)
        cov_test    = np.cov(test.T)

        mean_result = result.mean(axis=0)
        cov_result  = np.cov(result.T)
        ref_loc = mean_result.copy()
        # =========================
        # 2) Ellipse helper (yours)
        # =========================
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(np.maximum(eigvals, 0))
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)
            return ellipse

        # =========================
        # 3) Plot: prior vs post + path + ellipses
        # =========================
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)

        # scatter (keep s tiny; enlarge legend markers separately)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #     manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])
        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post (cond)", s=0.04, color="tab:orange")
        
        # covariance ellipses
        plot_cov_ellipse(cov_test,   mean_test,   ax, edgecolor="tab:blue", facecolor="none", linewidth=0.1,
                        label="Cov ellipse prior")
        plot_cov_ellipse(cov_result, mean_result, ax, edgecolor="tab:orange",  facecolor="none", linewidth=0.1,
                        label="Cov ellipse post")
        
        ax.axis("equal")

        ax.set_xlim(-100, 880)
        ax.set_ylim(-100, 800)
        ax.xaxis.set_major_locator(MultipleLocator(300))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(300))   # y-axis tick every 5

        ax.tick_params(axis='both', which='major', labelsize=24)
        ax.grid(alpha = 0.3)
        #ax.legend(markerscale=25)  # enlarge legend markers only
        plt.tight_layout()
        sigma_str = "mix"#f"{sigma_obs:g}".replace(".", "p")
        plt.show()
        plt.close()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## EnSF

# %% [markdown]
# ### ensemble-mean paths 100 iterations

# %%
testensf = EnSF(n_dim = N_dim, ensemble_size = ensemble_size ,eps_alpha=0.01, eps_beta= 0.00, device= use_this ,obs_sigma = 50, euler_steps = 1)
result1 = testensf.RSDE_incremental(obs=torch.tensor(600.0 * np.ones(10), device = use_this), x0=0, x_prior=test_sample.clone(), time_steps=100, ens_cov=covariance_matrix/295, sparse_idx=[i for i in range(10)],cov_scale = 295, tau_scale = 590) 

#path mean
x = (result1).cpu().detach().numpy()
for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        rotated_test_sample = test_sample[:,dim_plot] 
        d0, d1 = dim_plot[0], dim_plot[1]
        ref_loc = result_all[:, [d0, d1]].mean(axis=0)
        test = rotated_test_sample.cpu().numpy()  #rotated_test_sample
        result = ((result1[:,dim_plot,-1])) .cpu().numpy() #+test_sample[:,dim_plot]
        # Define the 2D covariance matrix
        cov_test = np.cov(test.T)
        cov_result = np.cov(result.T)

        # Mean of the distribution (center of the ellipse)
        mean_test = test.mean(axis = 0)
        mean_result = result.mean(axis = 0)
        # Generate samples from the multivariate normal distribution

        # Plot the samples
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #   manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])

        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post", s=0.04, color = "tab:orange")

        # Function to draw the covariance ellipse
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(eigvals)
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)

        # Draw the ellipse
        plot_cov_ellipse(cov_test,mean_test, ax, edgecolor='tab:blue', facecolor='none', linewidth=0.1, label='Covariance Ellipse Prior')
        plot_cov_ellipse(cov_result,mean_result, ax, edgecolor='tab:orange', facecolor='none', linewidth=0.1, label='Covariance Ellipse post')
        #mark the reference point
        ensf_path = x[:,dim_plot,:]
        px, py = ensf_path[:,0].mean(axis=0),ensf_path[:,1].mean(axis=0)
        plt.plot(px, py,'--',linewidth=1,color = "black", label='EnSF')

        def arrow_at(ax, x, y, idx, color='black', size=58, lw=1, back=50, tail_pt=0.5):
            """Open '>' arrowhead at point idx, oriented along the local path direction."""
            j = max(idx - back, 0)
            d = np.array([x[idx] - x[j], y[idx] - y[j]])
            d /= np.linalg.norm(d) + 1e-12
            ax.annotate('', xy=(x[idx], y[idx]),
                        xytext=(-tail_pt * d[0], -tail_pt * d[1]), textcoords='offset points',
                        arrowprops=dict(arrowstyle='->', color=color, mutation_scale=size,
                                        lw=lw, shrinkA=0, shrinkB=0), zorder=6)


        ax.scatter(mean_test[0], mean_test[1], marker='^', alpha=1, color ="tab:blue" ,label="reference", s=400)
        ax.scatter(mean_result[0], mean_result[1], marker='s',alpha=1, color ="black" ,label="reference", s=200)
        ax.axis('equal')

        ax.set_xlim(-100, 880)
        ax.set_ylim(-100, 800)
        ax.xaxis.set_major_locator(MultipleLocator(300))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(300))   # y-axis tick every 5
        ax.tick_params(axis='both', which='major', labelsize=24)

        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
        plt.close()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ## 3DEnVar

# %% [markdown]
# ### ensemble-mean paths

# %%
#full obs
H = lambda x: x
obs = torch.tensor(600.0 * np.ones(10), device = use_this)
# Create EnVar instance
# replace with __all__ = ['EnVar3D', 'CVT3dEnVar', 'CVT3dEnVarPerturbedObs', 'EnVar3DPerturbedObs']
envar = EnVar3D(H=H, y_obs=obs, B = covariance_matrix, R=torch.eye(N_dim)*2500.0, Xb= test_sample.clone(),obs_idx=[i for i in range(10)], learning_rate=0.005, max_iterations=50000, convergence_threshold=1e-6, device=use_this)

# Run assimilation
x_analysis,nan_idx, x_path = envar.run()

#path mean
plot_endpont = -1
x = (x_path).cpu().detach().numpy()
for i in range(1):
    for j in range(i+1,2):
        dim_plot = [i,j]
        rotated_test_sample = test_sample[:,dim_plot] 
        d0, d1 = dim_plot[0], dim_plot[1]
        ref_loc = result_all[:, [d0, d1]].mean(axis=0)
        test = rotated_test_sample.cpu().numpy()  #rotated_test_sample
        result = x[plot_endpont][:, dim_plot]
        # Define the 2D covariance matrix
        cov_test = np.cov(test.T)
        cov_result = np.cov(result.T)

        # Mean of the distribution (center of the ellipse)
        mean_test = test.mean(axis = 0)
        mean_result = result.mean(axis = 0)
        # Generate samples from the multivariate normal distribution

        # Plot the samples
        fig, ax = plt.subplots(figsize=(6, 6),dpi=50)
        # --- prior as Gaussian contour (replaces the prior scatter) ---
        pad = 0.1
        gx = np.linspace(test[:, 0].min() - pad * np.ptp(test[:, 0]),
                        test[:, 0].max() + pad * np.ptp(test[:, 0]), 400)
        gy = np.linspace(test[:, 1].min() - pad * np.ptp(test[:, 1]),
                        test[:, 1].max() + pad * np.ptp(test[:, 1]), 400)
        xx, yy = np.meshgrid(gx, gy)
        grid = np.stack([xx.ravel(), yy.ravel()], axis=1) - mean_test
        cov_inv = np.linalg.inv(cov_test)
        maha = np.sqrt(np.einsum('ij,jk,ik->i', grid, cov_inv, grid)).reshape(xx.shape)
        def on_contour(k, theta_deg):
            """Point on the k-sigma contour along direction theta (degrees in the data plane:
            0 = right, 90 = up, 45 = up the long axis, 135 = across the short axis)."""
            u = np.array([np.cos(np.radians(theta_deg)), np.sin(np.radians(theta_deg))])
            r = k / np.sqrt(u @ cov_inv @ u)
            return mean_test + r * u
        # filled shading (drop this line if you only want lines)
        ax.contourf(xx, yy, maha, levels=[0, 1, 2, 3], cmap='Blues_r', alpha=0.35)
        # contour lines at 1σ, 2σ, 3σ (Mahalanobis distance)
        cs = ax.contour(xx, yy, maha, levels=[1, 2, 3], colors='tab:blue', linewidths=0.8)
        # ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
        #   manual=[on_contour(1, 80), on_contour(2, 60), on_contour(3, 55)])
        ax.clabel(cs, fmt={1: r'1$\sigma$', 2: r'2$\sigma$', 3: r'3$\sigma$'}, fontsize=28,
            manual=[on_contour(1, 80), on_contour(2, 120), on_contour(3, 135)])

        ax.scatter(result[:, 0], result[:, 1], alpha=0.5, label="post", s=0.04, color = "tab:orange")

        # Function to draw the covariance ellipse
        def plot_cov_ellipse(cov, pos, ax, n_std=2.0, **kwargs):
            eigvals, eigvecs = np.linalg.eigh(cov)
            order = eigvals.argsort()[::-1]
            eigvals, eigvecs = eigvals[order], eigvecs[:, order]
            angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
            width, height = 2 * n_std * np.sqrt(eigvals)
            ellipse = Ellipse(xy=pos, width=width, height=height, angle=angle, **kwargs)
            ax.add_patch(ellipse)

        # Draw the ellipse
        plot_cov_ellipse(cov_test,mean_test, ax, edgecolor='tab:blue', facecolor='none', linewidth=0.1, label='Covariance Ellipse Prior')
        plot_cov_ellipse(cov_result,mean_result, ax, edgecolor='tab:orange', facecolor='none', linewidth=0.1, label='Covariance Ellipse post')
        #mark the reference point
        ensf_path = x[:plot_endpont,:,dim_plot].mean(axis=1)
        px, py = ensf_path[:, 0], ensf_path[:, 1]
        plt.plot(px, py,'--',linewidth=1,color = "black", label='EnSF')

        def arrow_at(ax, x, y, idx, color='black', size=58, lw=1, back=50, tail_pt=0.5):
            """Open '>' arrowhead at point idx, oriented along the local path direction."""
            j = max(idx - back, 0)
            d = np.array([x[idx] - x[j], y[idx] - y[j]])
            d /= np.linalg.norm(d) + 1e-12
            ax.annotate('', xy=(x[idx], y[idx]),
                        xytext=(-tail_pt * d[0], -tail_pt * d[1]), textcoords='offset points',
                        arrowprops=dict(arrowstyle='->', color=color, mutation_scale=size,
                                        lw=lw, shrinkA=0, shrinkB=0), zorder=6)


        ax.scatter(mean_test[0], mean_test[1], marker='^', alpha=1, color ="tab:blue" ,label="reference", s=400)
        ax.scatter(mean_result[0], mean_result[1], marker='s',alpha=1, color ="black" ,label="reference", s=200)
        ax.axis('equal')

        ax.set_xlim(-100, 880)
        ax.set_ylim(-100, 800)
        ax.xaxis.set_major_locator(MultipleLocator(300))   # x-axis tick every 5
        ax.yaxis.set_major_locator(MultipleLocator(300))   # y-axis tick every 5
        ax.tick_params(axis='both', which='major', labelsize=24)

        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.show()
        plt.close()
# Out:
# Iteration 1: Cost = 945.001892
# Iteration 2: Cost = 944.997986
# Iteration 3: Cost = 944.994263
# Iteration 4: Cost = 944.990601
# Iteration 5: Cost = 944.986755
# Iteration 6: Cost = 944.982971
# Iteration 7: Cost = 944.979187
# Iteration 8: Cost = 944.975403
# Iteration 9: Cost = 944.971558
# Iteration 10: Cost = 944.967773
# Iteration 11: Cost = 944.964050
# Iteration 12: Cost = 944.960266
# Iteration 13: Cost = 944.956482
# Iteration 14: Cost = 944.952698
# Iteration 15: Cost = 944.948853
# Iteration 16: Cost = 944.945190
# Iteration 17: Cost = 944.941406
# Iteration 18: Cost = 944.937561
# Iteration 19: Cost = 944.933777
# Iteration 20: Cost = 944.929993
# Iteration 21: Cost = 944.926270
# Iteration 22: Cost = 944.922485
# Iteration 23: Cost = 944.918701
# Iteration 24: Cost = 944.914856
# Iteration 25: Cost = 944.911194
# Iteration 26: Cost = 944.907349
# Iteration 27: Cost = 944.903564
# Iteration 28: Cost = 944.899780
# Iteration 29: Cost = 944.895996
# Iteration 30: Cost = 944.892273
# Iteration 31: Cost = 944.888367
# Iteration 32: Cost = 944.884705
# Iteration 33: Cost = 944.880981
# Iteration 34: Cost = 944.877075
# Iteration 35: Cost = 944.873352
# Iteration 36: Cost = 944.869568
# Iteration 37: Cost = 944.865784
# Iteration 38: Cost = 944.862000
# Iteration 39: Cost = 944.858154
# Iteration 40: Cost = 944.854370
# Iteration 41: Cost = 944.850586
# Iteration 42: Cost = 944.846863
# Iteration 43: Cost = 944.843079
# Iteration 44: Cost = 944.839355
# Iteration 45: Cost = 944.835571
# Iteration 46: Cost = 944.831787
# Iteration 47: Cost = 944.828003
# Iteration 48: Cost = 944.824158
# Iteration 49: Cost = 944.820374
# Iteration 50: Cost = 944.816589
# Iteration 51: Cost = 944.812805
# Iteration 52: Cost = 944.809204
# Iteration 53: Cost = 944.805298
# Iteration 54: Cost = 944.801575
# Iteration 55: Cost = 944.797791
# Iteration 56: Cost = 944.794006
# Iteration 57: Cost = 944.790161
# Iteration 58: Cost = 944.786377
# Iteration 59: Cost = 944.782593
# Iteration 60: Cost = 944.778748
# Iteration 61: Cost = 944.774963
# Iteration 62: Cost = 944.771362
# Iteration 63: Cost = 944.767456
# Iteration 64: Cost = 944.763794
# Iteration 65: Cost = 944.759949
# Iteration 66: Cost = 944.756165
# Iteration 67: Cost = 944.752380
# Iteration 68: Cost = 944.748596
# Iteration 69: Cost = 944.744751
# Iteration 70: Cost = 944.741089
# Iteration 71: Cost = 944.737183
# Iteration 72: Cost = 944.733582
# Iteration 73: Cost = 944.729797
# Iteration 74: Cost = 944.725952
# Iteration 75: Cost = 944.722168
# Iteration 76: Cost = 944.718384
# Iteration 77: Cost = 944.714600
# Iteration 78: Cost = 944.710754
# Iteration 79: Cost = 944.706970
# Iteration 80: Cost = 944.703186
# Iteration 81: Cost = 944.699463
# Iteration 82: Cost = 944.695801
# Iteration 83: Cost = 944.691956
# Iteration 84: Cost = 944.688171
# Iteration 85: Cost = 944.684387
# Iteration 86: Cost = 944.680603
# Iteration 87: Cost = 944.676880
# Iteration 88: Cost = 944.673096
# Iteration 89: Cost = 944.669250
# Iteration 90: Cost = 944.665466
# Iteration 91: Cost = 944.661682
# Iteration 92: Cost = 944.657898
# Iteration 93: Cost = 944.654175
# Iteration 94: Cost = 944.650391
# Iteration 95: Cost = 944.646606
# Iteration 96: Cost = 944.642761
# Iteration 97: Cost = 944.638977
# Iteration 98: Cost = 944.635254
# Iteration 99: Cost = 944.631470
# Iteration 100: Cost = 944.627686
# Iteration 101: Cost = 944.623962
# Iteration 102: Cost = 944.620178
# Iteration 103: Cost = 944.616394
# Iteration 104: Cost = 944.612549
# Iteration 105: Cost = 944.608887
# Iteration 106: Cost = 944.604980
# Iteration 107: Cost = 944.601196
# Iteration 108: Cost = 944.597473
# Iteration 109: Cost = 944.593750
# Iteration 110: Cost = 944.589905
# Iteration 111: Cost = 944.586182
# Iteration 112: Cost = 944.582397
# Iteration 113: Cost = 944.578552
# Iteration 114: Cost = 944.574768
# Iteration 115: Cost = 944.571106
# Iteration 116: Cost = 944.567200
# Iteration 117: Cost = 944.563354
# Iteration 118: Cost = 944.559692
# Iteration 119: Cost = 944.555969
# Iteration 120: Cost = 944.552063
# Iteration 121: Cost = 944.548401
# Iteration 122: Cost = 944.544556
# Iteration 123: Cost = 944.540771
# Iteration 124: Cost = 944.536987
# Iteration 125: Cost = 944.533203
# Iteration 126: Cost = 944.529358
# Iteration 127: Cost = 944.525696
# Iteration 128: Cost = 944.521851
# Iteration 129: Cost = 944.518188
# Iteration 130: Cost = 944.514404
# Iteration 131: Cost = 944.510559
# Iteration 132: Cost = 944.506775
# Iteration 133: Cost = 944.502991
# Iteration 134: Cost = 944.499207
# Iteration 135: Cost = 944.495361
# Iteration 136: Cost = 944.491699
# Iteration 137: Cost = 944.487976
# Iteration 138: Cost = 944.484192
# Iteration 139: Cost = 944.480347
# Iteration 140: Cost = 944.476562
# Iteration 141: Cost = 944.472778
# Iteration 142: Cost = 944.468994
# Iteration 143: Cost = 944.465149
# Iteration 144: Cost = 944.461548
# Iteration 145: Cost = 944.457581
# Iteration 146: Cost = 944.453979
# Iteration 147: Cost = 944.450195
# Iteration 148: Cost = 944.446350
# Iteration 149: Cost = 944.442566
# Iteration 150: Cost = 944.438782
# Iteration 151: Cost = 944.434998
# Iteration 152: Cost = 944.431152
# Iteration 153: Cost = 944.427368
# Iteration 154: Cost = 944.423706
# Iteration 155: Cost = 944.419861
# Iteration 156: Cost = 944.416199
# Iteration 157: Cost = 944.412354
# Iteration 158: Cost = 944.408569
# Iteration 159: Cost = 944.404785
# Iteration 160: Cost = 944.401001
# Iteration 161: Cost = 944.397156
# Iteration 162: Cost = 944.393494
# Iteration 163: Cost = 944.389648
# Iteration 164: Cost = 944.385864
# Iteration 165: Cost = 944.382202
# Iteration 166: Cost = 944.378357
# Iteration 167: Cost = 944.374573
# Iteration 168: Cost = 944.370789
# Iteration 169: Cost = 944.367004
# Iteration 170: Cost = 944.363159
# Iteration 171: Cost = 944.359497
# Iteration 172: Cost = 944.355652
# Iteration 173: Cost = 944.351868
# Iteration 174: Cost = 944.348206
# Iteration 175: Cost = 944.344299
# Iteration 176: Cost = 944.340576
# Iteration 177: Cost = 944.336853
# Iteration 178: Cost = 944.332947
# Iteration 179: Cost = 944.329163
# Iteration 180: Cost = 944.325500
# Iteration 181: Cost = 944.321655
# Iteration 182: Cost = 944.317871
# Iteration 183: Cost = 944.314148
# Iteration 184: Cost = 944.310364
# Iteration 185: Cost = 944.306580
# Iteration 186: Cost = 944.302795
# Iteration 187: Cost = 944.299072
# Iteration 188: Cost = 944.295288
# Iteration 189: Cost = 944.291504
# Iteration 190: Cost = 944.287659
# Iteration 191: Cost = 944.283997
# Iteration 192: Cost = 944.280090
# Iteration 193: Cost = 944.276367
# Iteration 194: Cost = 944.272583
# Iteration 195: Cost = 944.268860
# Iteration 196: Cost = 944.264954
# Iteration 197: Cost = 944.261169
# Iteration 198: Cost = 944.257446
# Iteration 199: Cost = 944.253784
# Iteration 200: Cost = 944.249878
# Iteration 201: Cost = 944.246155
# Iteration 202: Cost = 944.242371
# Iteration 203: Cost = 944.238586
# Iteration 204: Cost = 944.234802
# Iteration 205: Cost = 944.230957
# Iteration 206: Cost = 944.227173
# Iteration 207: Cost = 944.223450
# Iteration 208: Cost = 944.219666
# Iteration 209: Cost = 944.216003
# Iteration 210: Cost = 944.212158
# Iteration 211: Cost = 944.208374
# Iteration 212: Cost = 944.204590
# Iteration 213: Cost = 944.200806
# Iteration 214: Cost = 944.196960
# Iteration 215: Cost = 944.193298
# Iteration 216: Cost = 944.189453
# Iteration 217: Cost = 944.185791
# Iteration 218: Cost = 944.181946
# Iteration 219: Cost = 944.178162
# Iteration 220: Cost = 944.174377
# Iteration 221: Cost = 944.170593
# Iteration 222: Cost = 944.166748
# Iteration 223: Cost = 944.162964
# Iteration 224: Cost = 944.159302
# Iteration 225: Cost = 944.155579
# Iteration 226: Cost = 944.151794
# Iteration 227: Cost = 944.147949
# Iteration 228: Cost = 944.144165
# Iteration 229: Cost = 944.140381
# Iteration 230: Cost = 944.136597
# Iteration 231: Cost = 944.132751
# Iteration 232: Cost = 944.129089
# Iteration 233: Cost = 944.125366
# Iteration 234: Cost = 944.121582
# Iteration 235: Cost = 944.117798
# Iteration 236: Cost = 944.113953
# Iteration 237: Cost = 944.110168
# Iteration 238: Cost = 944.106384
# Iteration 239: Cost = 944.102600
# Iteration 240: Cost = 944.098877
# Iteration 241: Cost = 944.095093
# Iteration 242: Cost = 944.091248
# Iteration 243: Cost = 944.087585
# Iteration 244: Cost = 944.083801
# Iteration 245: Cost = 944.079956
# Iteration 246: Cost = 944.076172
# Iteration 247: Cost = 944.072449
# Iteration 248: Cost = 944.068665
# Iteration 249: Cost = 944.064758
# Iteration 250: Cost = 944.061157
# Iteration 251: Cost = 944.057373
# Iteration 252: Cost = 944.053589
# Iteration 253: Cost = 944.049805
# Iteration 254: Cost = 944.046082
# Iteration 255: Cost = 944.042175
# Iteration 256: Cost = 944.038391
# Iteration 257: Cost = 944.034668
# Iteration 258: Cost = 944.030884
# Iteration 259: Cost = 944.027161
# Iteration 260: Cost = 944.023254
# Iteration 261: Cost = 944.019592
# Iteration 262: Cost = 944.015747
# Iteration 263: Cost = 944.011963
# Iteration 264: Cost = 944.008179
# Iteration 265: Cost = 944.004456
# Iteration 266: Cost = 944.000671
# Iteration 267: Cost = 943.996887
# Iteration 268: Cost = 943.993164
# Iteration 269: Cost = 943.989258
# Iteration 270: Cost = 943.985596
# Iteration 271: Cost = 943.981750
# Iteration 272: Cost = 943.977966
# Iteration 273: Cost = 943.974304
# Iteration 274: Cost = 943.970459
# Iteration 275: Cost = 943.966675
# Iteration 276: Cost = 943.962891
# Iteration 277: Cost = 943.959167
# Iteration 278: Cost = 943.955383
# Iteration 279: Cost = 943.951599
# Iteration 280: Cost = 943.947876
# Iteration 281: Cost = 943.943970
# Iteration 282: Cost = 943.940247
# Iteration 283: Cost = 943.936584
# Iteration 284: Cost = 943.932800
# Iteration 285: Cost = 943.928955
# Iteration 286: Cost = 943.925171
# Iteration 287: Cost = 943.921387
# Iteration 288: Cost = 943.917603
# Iteration 289: Cost = 943.913757
# Iteration 290: Cost = 943.909973
# Iteration 291: Cost = 943.906189
# Iteration 292: Cost = 943.902466
# Iteration 293: Cost = 943.898804
# Iteration 294: Cost = 943.894958
# Iteration 295: Cost = 943.891174
# Iteration 296: Cost = 943.887390
# Iteration 297: Cost = 943.883606
# Iteration 298: Cost = 943.879761
# Iteration 299: Cost = 943.876099
# Iteration 300: Cost = 943.872375
# Iteration 301: Cost = 943.868591
# Iteration 302: Cost = 943.864746
# Iteration 303: Cost = 943.860962
# Iteration 304: Cost = 943.857178
# Iteration 305: Cost = 943.853394
# Iteration 306: Cost = 943.849548
# Iteration 307: Cost = 943.845886
# Iteration 308: Cost = 943.842163
# Iteration 309: Cost = 943.838379
# Iteration 310: Cost = 943.834595
# Iteration 311: Cost = 943.830750
# Iteration 312: Cost = 943.826965
# Iteration 313: Cost = 943.823181
# Iteration 314: Cost = 943.819397
# Iteration 315: Cost = 943.815674
# Iteration 316: Cost = 943.811951
# Iteration 317: Cost = 943.808167
# Iteration 318: Cost = 943.804382
# Iteration 319: Cost = 943.800598
# Iteration 320: Cost = 943.796753
# Iteration 321: Cost = 943.792969
# Iteration 322: Cost = 943.789185
# Iteration 323: Cost = 943.785400
# Iteration 324: Cost = 943.781799
# Iteration 325: Cost = 943.777954
# Iteration 326: Cost = 943.774170
# Iteration 327: Cost = 943.770386
# Iteration 328: Cost = 943.766602
# Iteration 329: Cost = 943.762756
# Iteration 330: Cost = 943.758972
# Iteration 331: Cost = 943.755188
# Iteration 332: Cost = 943.751587
# Iteration 333: Cost = 943.747803
# Iteration 334: Cost = 943.743958
# Iteration 335: Cost = 943.740173
# Iteration 336: Cost = 943.736389
# Iteration 337: Cost = 943.732605
# Iteration 338: Cost = 943.728882
# Iteration 339: Cost = 943.725098
# Iteration 340: Cost = 943.721252
# Iteration 341: Cost = 943.717468
# Iteration 342: Cost = 943.713806
# Iteration 343: Cost = 943.709961
# Iteration 344: Cost = 943.706177
# Iteration 345: Cost = 943.702454
# Iteration 346: Cost = 943.698547
# Iteration 347: Cost = 943.694885
# Iteration 348: Cost = 943.691101
# Iteration 349: Cost = 943.687378
# Iteration 350: Cost = 943.683594
# Iteration 351: Cost = 943.679749
# Iteration 352: Cost = 943.675964
# Iteration 353: Cost = 943.672302
# Iteration 354: Cost = 943.668396
# Iteration 355: Cost = 943.664673
# Iteration 356: Cost = 943.660889
# Iteration 357: Cost = 943.657104
# Iteration 358: Cost = 943.653381
# Iteration 359: Cost = 943.649597
# Iteration 360: Cost = 943.645752
# Iteration 361: Cost = 943.642090
# Iteration 362: Cost = 943.638306
# Iteration 363: Cost = 943.634460
# Iteration 364: Cost = 943.630676
# Iteration 365: Cost = 943.626953
# Iteration 366: Cost = 943.623169
# Iteration 367: Cost = 943.619385
# Iteration 368: Cost = 943.615601
# Iteration 369: Cost = 943.611755
# Iteration 370: Cost = 943.608093
# Iteration 371: Cost = 943.604370
# Iteration 372: Cost = 943.600464
# Iteration 373: Cost = 943.596802
# Iteration 374: Cost = 943.592957
# Iteration 375: Cost = 943.589172
# Iteration 376: Cost = 943.585388
# Iteration 377: Cost = 943.581665
# Iteration 378: Cost = 943.577759
# Iteration 379: Cost = 943.574097
# Iteration 380: Cost = 943.570374
# Iteration 381: Cost = 943.566589
# Iteration 382: Cost = 943.562805
# Iteration 383: Cost = 943.558960
# Iteration 384: Cost = 943.555176
# Iteration 385: Cost = 943.551392
# Iteration 386: Cost = 943.547668
# Iteration 387: Cost = 943.544006
# Iteration 388: Cost = 943.540161
# Iteration 389: Cost = 943.536377
# Iteration 390: Cost = 943.532593
# Iteration 391: Cost = 943.528748
# Iteration 392: Cost = 943.524963
# Iteration 393: Cost = 943.521179
# Iteration 394: Cost = 943.517456
# Iteration 395: Cost = 943.513794
# Iteration 396: Cost = 943.509949
# Iteration 397: Cost = 943.506165
# Iteration 398: Cost = 943.502380
# Iteration 399: Cost = 943.498596
# Iteration 400: Cost = 943.494751
# Iteration 401: Cost = 943.491089
# Iteration 402: Cost = 943.487183
# Iteration 403: Cost = 943.483459
# Iteration 404: Cost = 943.479797
# Iteration 405: Cost = 943.475952
# Iteration 406: Cost = 943.472168
# Iteration 407: Cost = 943.468384
# Iteration 408: Cost = 943.464600
# Iteration 409: Cost = 943.460876
# Iteration 410: Cost = 943.457092
# Iteration 411: Cost = 943.453369
# Iteration 412: Cost = 943.449585
# Iteration 413: Cost = 943.445801
# Iteration 414: Cost = 943.441956
# Iteration 415: Cost = 943.438171
# Iteration 416: Cost = 943.434387
# Iteration 417: Cost = 943.430664
# Iteration 418: Cost = 943.426880
# Iteration 419: Cost = 943.423157
# Iteration 420: Cost = 943.419373
# Iteration 421: Cost = 943.415588
# Iteration 422: Cost = 943.411804
# Iteration 423: Cost = 943.407959
# Iteration 424: Cost = 943.404297
# Iteration 425: Cost = 943.400452
# Iteration 426: Cost = 943.396790
# Iteration 427: Cost = 943.393005
# Iteration 428: Cost = 943.389160
# Iteration 429: Cost = 943.385376
# Iteration 430: Cost = 943.381592
# Iteration 431: Cost = 943.377869
# Iteration 432: Cost = 943.373962
# Iteration 433: Cost = 943.370300
# Iteration 434: Cost = 943.366577
# Iteration 435: Cost = 943.362793
# Iteration 436: Cost = 943.358948
# Iteration 437: Cost = 943.355164
# Iteration 438: Cost = 943.351501
# Iteration 439: Cost = 943.347656
# Iteration 440: Cost = 943.343872
# Iteration 441: Cost = 943.340088
# Iteration 442: Cost = 943.336304
# Iteration 443: Cost = 943.332581
# Iteration 444: Cost = 943.328796
# Iteration 445: Cost = 943.325073
# Iteration 446: Cost = 943.321289
# Iteration 447: Cost = 943.317505
# Iteration 448: Cost = 943.313660
# Iteration 449: Cost = 943.309998
# Iteration 450: Cost = 943.306152
# Iteration 451: Cost = 943.302368
# Iteration 452: Cost = 943.298584
# Iteration 453: Cost = 943.294861
# Iteration 454: Cost = 943.291077
# Iteration 455: Cost = 943.287292
# Iteration 456: Cost = 943.283447
# Iteration 457: Cost = 943.279785
# Iteration 458: Cost = 943.276001
# Iteration 459: Cost = 943.272156
# Iteration 460: Cost = 943.268372
# Iteration 461: Cost = 943.264587
# Iteration 462: Cost = 943.260803
# Iteration 463: Cost = 943.257202
# Iteration 464: Cost = 943.253357
# Iteration 465: Cost = 943.249573
# Iteration 466: Cost = 943.245789
# Iteration 467: Cost = 943.242004
# Iteration 468: Cost = 943.238159
# Iteration 469: Cost = 943.234497
# Iteration 470: Cost = 943.230652
# Iteration 471: Cost = 943.226868
# Iteration 472: Cost = 943.223206
# Iteration 473: Cost = 943.219360
# Iteration 474: Cost = 943.215576
# Iteration 475: Cost = 943.211792
# Iteration 476: Cost = 943.207947
# Iteration 477: Cost = 943.204285
# Iteration 478: Cost = 943.200500
# Iteration 479: Cost = 943.196777
# Iteration 480: Cost = 943.192993
# Iteration 481: Cost = 943.189148
# Iteration 482: Cost = 943.185364
# Iteration 483: Cost = 943.181580
# Iteration 484: Cost = 943.177856
# Iteration 485: Cost = 943.174072
# Iteration 486: Cost = 943.170349
# Iteration 487: Cost = 943.166565
# Iteration 488: Cost = 943.162781
# Iteration 489: Cost = 943.158997
# Iteration 490: Cost = 943.155151
# Iteration 491: Cost = 943.151550
# Iteration 492: Cost = 943.147705
# Iteration 493: Cost = 943.143982
# Iteration 494: Cost = 943.140198
# Iteration 495: Cost = 943.136353
# Iteration 496: Cost = 943.132568
# Iteration 497: Cost = 943.128784
# Iteration 498: Cost = 943.125061
# Iteration 499: Cost = 943.121277
# Iteration 500: Cost = 943.117493
# Iteration 501: Cost = 943.113770
# Iteration 502: Cost = 943.109985
# Iteration 503: Cost = 943.106201
# Iteration 504: Cost = 943.102356
# Iteration 505: Cost = 943.098572
# Iteration 506: Cost = 943.094849
# Iteration 507: Cost = 943.091064
# Iteration 508: Cost = 943.087402
# Iteration 509: Cost = 943.083557
# Iteration 510: Cost = 943.079773
# Iteration 511: Cost = 943.076050
# Iteration 512: Cost = 943.072266
# Iteration 513: Cost = 943.068481
# Iteration 514: Cost = 943.064697
# Iteration 515: Cost = 943.060852
# Iteration 516: Cost = 943.057190
# Iteration 517: Cost = 943.053406
# Iteration 518: Cost = 943.049561
# Iteration 519: Cost = 943.045898
# Iteration 520: Cost = 943.042053
# Iteration 521: Cost = 943.038269
# Iteration 522: Cost = 943.034485
# Iteration 523: Cost = 943.030762
# Iteration 524: Cost = 943.026978
# Iteration 525: Cost = 943.023193
# Iteration 526: Cost = 943.019348
# Iteration 527: Cost = 943.015686
# Iteration 528: Cost = 943.011902
# Iteration 529: Cost = 943.008057
# Iteration 530: Cost = 943.004272
# Iteration 531: Cost = 943.000549
# Iteration 532: Cost = 942.996765
# Iteration 533: Cost = 942.992981
# Iteration 534: Cost = 942.989258
# Iteration 535: Cost = 942.985474
# Iteration 536: Cost = 942.981689
# Iteration 537: Cost = 942.977966
# Iteration 538: Cost = 942.974182
# Iteration 539: Cost = 942.970398
# Iteration 540: Cost = 942.966675
# Iteration 541: Cost = 942.962769
# Iteration 542: Cost = 942.959106
# Iteration 543: Cost = 942.955261
# Iteration 544: Cost = 942.951599
# Iteration 545: Cost = 942.947754
# Iteration 546: Cost = 942.943970
# Iteration 547: Cost = 942.940186
# Iteration 548: Cost = 942.936462
# Iteration 549: Cost = 942.932556
# Iteration 550: Cost = 942.928955
# Iteration 551: Cost = 942.925049
# Iteration 552: Cost = 942.921387
# Iteration 553: Cost = 942.917603
# Iteration 554: Cost = 942.913757
# Iteration 555: Cost = 942.909973
# Iteration 556: Cost = 942.906189
# Iteration 557: Cost = 942.902466
# Iteration 558: Cost = 942.898804
# Iteration 559: Cost = 942.894958
# Iteration 560: Cost = 942.891174
# Iteration 561: Cost = 942.887390
# Iteration 562: Cost = 942.883606
# Iteration 563: Cost = 942.880005
# Iteration 564: Cost = 942.876160
# Iteration 565: Cost = 942.872375
# Iteration 566: Cost = 942.868591
# Iteration 567: Cost = 942.864746
# Iteration 568: Cost = 942.860962
# Iteration 569: Cost = 942.857178
# Iteration 570: Cost = 942.853455
# Iteration 571: Cost = 942.849670
# Iteration 572: Cost = 942.845947
# Iteration 573: Cost = 942.842163
# Iteration 574: Cost = 942.838379
# Iteration 575: Cost = 942.834595
# Iteration 576: Cost = 942.830750
# Iteration 577: Cost = 942.827087
# Iteration 578: Cost = 942.823364
# Iteration 579: Cost = 942.819458
# Iteration 580: Cost = 942.815796
# Iteration 581: Cost = 942.811951
# Iteration 582: Cost = 942.808167
# Iteration 583: Cost = 942.804382
# Iteration 584: Cost = 942.800659
# Iteration 585: Cost = 942.796875
# Iteration 586: Cost = 942.793152
# Iteration 587: Cost = 942.789368
# Iteration 588: Cost = 942.785583
# Iteration 589: Cost = 942.781860
# Iteration 590: Cost = 942.777954
# Iteration 591: Cost = 942.774292
# Iteration 592: Cost = 942.770447
# Iteration 593: Cost = 942.766785
# Iteration 594: Cost = 942.763000
# Iteration 595: Cost = 942.759155
# Iteration 596: Cost = 942.755371
# Iteration 597: Cost = 942.751648
# Iteration 598: Cost = 942.747864
# Iteration 599: Cost = 942.744080
# Iteration 600: Cost = 942.740356
# Iteration 601: Cost = 942.736572
# Iteration 602: Cost = 942.732788
# Iteration 603: Cost = 942.729065
# Iteration 604: Cost = 942.725281
# Iteration 605: Cost = 942.721497
# Iteration 606: Cost = 942.717651
# Iteration 607: Cost = 942.713989
# Iteration 608: Cost = 942.710205
# Iteration 609: Cost = 942.706360
# Iteration 610: Cost = 942.702698
# Iteration 611: Cost = 942.698792
# Iteration 612: Cost = 942.695068
# Iteration 613: Cost = 942.691284
# Iteration 614: Cost = 942.687561
# Iteration 615: Cost = 942.683777
# Iteration 616: Cost = 942.680054
# Iteration 617: Cost = 942.676270
# Iteration 618: Cost = 942.672485
# Iteration 619: Cost = 942.668762
# Iteration 620: Cost = 942.664856
# Iteration 621: Cost = 942.661194
# Iteration 622: Cost = 942.657349
# Iteration 623: Cost = 942.653564
# Iteration 624: Cost = 942.649780
# Iteration 625: Cost = 942.645996
# Iteration 626: Cost = 942.642273
# Iteration 627: Cost = 942.638550
# Iteration 628: Cost = 942.634766
# Iteration 629: Cost = 942.630981
# Iteration 630: Cost = 942.627197
# Iteration 631: Cost = 942.623352
# Iteration 632: Cost = 942.619568
# Iteration 633: Cost = 942.615967
# Iteration 634: Cost = 942.612183
# Iteration 635: Cost = 942.608398
# Iteration 636: Cost = 942.604553
# Iteration 637: Cost = 942.600769
# Iteration 638: Cost = 942.597168
# Iteration 639: Cost = 942.593262
# Iteration 640: Cost = 942.589478
# Iteration 641: Cost = 942.585754
# Iteration 642: Cost = 942.581970
# Iteration 643: Cost = 942.578186
# Iteration 644: Cost = 942.574402
# Iteration 645: Cost = 942.570557
# Iteration 646: Cost = 942.566895
# Iteration 647: Cost = 942.563171
# Iteration 648: Cost = 942.559387
# Iteration 649: Cost = 942.555603
# Iteration 650: Cost = 942.551758
# Iteration 651: Cost = 942.547974
# Iteration 652: Cost = 942.544250
# Iteration 653: Cost = 942.540588
# Iteration 654: Cost = 942.536804
# Iteration 655: Cost = 942.532959
# Iteration 656: Cost = 942.529175
# Iteration 657: Cost = 942.525391
# Iteration 658: Cost = 942.521606
# Iteration 659: Cost = 942.517761
# Iteration 660: Cost = 942.514160
# Iteration 661: Cost = 942.510376
# Iteration 662: Cost = 942.506592
# Iteration 663: Cost = 942.502747
# Iteration 664: Cost = 942.498962
# Iteration 665: Cost = 942.495178
# Iteration 666: Cost = 942.491455
# Iteration 667: Cost = 942.487671
# Iteration 668: Cost = 942.483948
# Iteration 669: Cost = 942.480164
# Iteration 670: Cost = 942.476379
# Iteration 671: Cost = 942.472595
# Iteration 672: Cost = 942.468750
# Iteration 673: Cost = 942.465088
# Iteration 674: Cost = 942.461304
# Iteration 675: Cost = 942.457581
# Iteration 676: Cost = 942.453796
# Iteration 677: Cost = 942.449951
# Iteration 678: Cost = 942.446289
# Iteration 679: Cost = 942.442505
# Iteration 680: Cost = 942.438782
# Iteration 681: Cost = 942.434998
# Iteration 682: Cost = 942.431152
# Iteration 683: Cost = 942.427368
# Iteration 684: Cost = 942.423706
# Iteration 685: Cost = 942.419861
# Iteration 686: Cost = 942.416077
# Iteration 687: Cost = 942.412354
# Iteration 688: Cost = 942.408447
# Iteration 689: Cost = 942.404785
# Iteration 690: Cost = 942.401001
# Iteration 691: Cost = 942.397278
# Iteration 692: Cost = 942.393494
# Iteration 693: Cost = 942.389648
# Iteration 694: Cost = 942.385986
# Iteration 695: Cost = 942.382080
# Iteration 696: Cost = 942.378479
# Iteration 697: Cost = 942.374573
# Iteration 698: Cost = 942.370789
# Iteration 699: Cost = 942.367065
# Iteration 700: Cost = 942.363403
# Iteration 701: Cost = 942.359558
# Iteration 702: Cost = 942.355774
# Iteration 703: Cost = 942.351990
# Iteration 704: Cost = 942.348267
# Iteration 705: Cost = 942.344360
# Iteration 706: Cost = 942.340698
# Iteration 707: Cost = 942.336975
# Iteration 708: Cost = 942.333191
# Iteration 709: Cost = 942.329346
# Iteration 710: Cost = 942.325562
# Iteration 711: Cost = 942.321899
# Iteration 712: Cost = 942.317993
# Iteration 713: Cost = 942.314270
# Iteration 714: Cost = 942.310547
# Iteration 715: Cost = 942.306763
# Iteration 716: Cost = 942.302979
# Iteration 717: Cost = 942.299194
# Iteration 718: Cost = 942.295349
# Iteration 719: Cost = 942.291748
# Iteration 720: Cost = 942.287964
# Iteration 721: Cost = 942.284180
# Iteration 722: Cost = 942.280396
# Iteration 723: Cost = 942.276550
# Iteration 724: Cost = 942.272766
# Iteration 725: Cost = 942.269165
# Iteration 726: Cost = 942.265259
# Iteration 727: Cost = 942.261597
# Iteration 728: Cost = 942.257751
# Iteration 729: Cost = 942.253967
# Iteration 730: Cost = 942.250305
# Iteration 731: Cost = 942.246460
# Iteration 732: Cost = 942.242798
# Iteration 733: Cost = 942.238953
# Iteration 734: Cost = 942.235168
# Iteration 735: Cost = 942.231384
# Iteration 736: Cost = 942.227600
# Iteration 737: Cost = 942.223755
# Iteration 738: Cost = 942.220154
# Iteration 739: Cost = 942.216370
# Iteration 740: Cost = 942.212585
# Iteration 741: Cost = 942.208801
# Iteration 742: Cost = 942.204956
# Iteration 743: Cost = 942.201172
# Iteration 744: Cost = 942.197388
# Iteration 745: Cost = 942.193787
# Iteration 746: Cost = 942.190002
# Iteration 747: Cost = 942.186157
# Iteration 748: Cost = 942.182373
# Iteration 749: Cost = 942.178589
# Iteration 750: Cost = 942.174866
# Iteration 751: Cost = 942.171082
# Iteration 752: Cost = 942.167358
# Iteration 753: Cost = 942.163574
# Iteration 754: Cost = 942.159790
# Iteration 755: Cost = 942.156006
# Iteration 756: Cost = 942.152161
# Iteration 757: Cost = 942.148499
# Iteration 758: Cost = 942.144653
# Iteration 759: Cost = 942.140991
# Iteration 760: Cost = 942.137146
# Iteration 761: Cost = 942.133362
# Iteration 762: Cost = 942.129578
# Iteration 763: Cost = 942.125854
# Iteration 764: Cost = 942.122070
# Iteration 765: Cost = 942.118286
# Iteration 766: Cost = 942.114563
# Iteration 767: Cost = 942.110901
# Iteration 768: Cost = 942.106995
# Iteration 769: Cost = 942.103271
# Iteration 770: Cost = 942.099487
# Iteration 771: Cost = 942.095764
# Iteration 772: Cost = 942.091980
# Iteration 773: Cost = 942.088196
# Iteration 774: Cost = 942.084473
# Iteration 775: Cost = 942.080688
# Iteration 776: Cost = 942.076904
# Iteration 777: Cost = 942.073181
# Iteration 778: Cost = 942.069275
# Iteration 779: Cost = 942.065552
# Iteration 780: Cost = 942.061890
# Iteration 781: Cost = 942.058105
# Iteration 782: Cost = 942.054260
# Iteration 783: Cost = 942.050476
# Iteration 784: Cost = 942.046753
# Iteration 785: Cost = 942.042969
# Iteration 786: Cost = 942.039185
# Iteration 787: Cost = 942.035400
# Iteration 788: Cost = 942.031677
# Iteration 789: Cost = 942.027954
# Iteration 790: Cost = 942.024170
# Iteration 791: Cost = 942.020386
# Iteration 792: Cost = 942.016602
# Iteration 793: Cost = 942.012756
# Iteration 794: Cost = 942.009155
# Iteration 795: Cost = 942.005371
# Iteration 796: Cost = 942.001587
# Iteration 797: Cost = 941.997803
# Iteration 798: Cost = 941.993958
# Iteration 799: Cost = 941.990173
# Iteration 800: Cost = 941.986450
# Iteration 801: Cost = 941.982666
# Iteration 802: Cost = 941.979004
# Iteration 803: Cost = 941.975159
# Iteration 804: Cost = 941.971375
# Iteration 805: Cost = 941.967590
# Iteration 806: Cost = 941.963806
# Iteration 807: Cost = 941.960083
# Iteration 808: Cost = 941.956360
# Iteration 809: Cost = 941.952576
# Iteration 810: Cost = 941.948792
# Iteration 811: Cost = 941.944946
# Iteration 812: Cost = 941.941162
# Iteration 813: Cost = 941.937378
# Iteration 814: Cost = 941.933777
# Iteration 815: Cost = 941.929993
# Iteration 816: Cost = 941.926147
# Iteration 817: Cost = 941.922363
# Iteration 818: Cost = 941.918579
# Iteration 819: Cost = 941.914978
# Iteration 820: Cost = 941.911194
# Iteration 821: Cost = 941.907288
# Iteration 822: Cost = 941.903564
# Iteration 823: Cost = 941.899780
# Iteration 824: Cost = 941.895996
# Iteration 825: Cost = 941.892273
# Iteration 826: Cost = 941.888489
# Iteration 827: Cost = 941.884766
# Iteration 828: Cost = 941.880981
# Iteration 829: Cost = 941.877197
# Iteration 830: Cost = 941.873352
# Iteration 831: Cost = 941.869568
# Iteration 832: Cost = 941.865967
# Iteration 833: Cost = 941.862061
# Iteration 834: Cost = 941.858398
# Iteration 835: Cost = 941.854553
# Iteration 836: Cost = 941.850769
# Iteration 837: Cost = 941.847046
# Iteration 838: Cost = 941.843262
# Iteration 839: Cost = 941.839600
# Iteration 840: Cost = 941.835754
# Iteration 841: Cost = 941.831970
# Iteration 842: Cost = 941.828186
# Iteration 843: Cost = 941.824463
# Iteration 844: Cost = 941.820679
# Iteration 845: Cost = 941.816895
# Iteration 846: Cost = 941.813171
# Iteration 847: Cost = 941.809387
# Iteration 848: Cost = 941.805603
# Iteration 849: Cost = 941.801880
# Iteration 850: Cost = 941.798096
# Iteration 851: Cost = 941.794373
# Iteration 852: Cost = 941.790466
# Iteration 853: Cost = 941.786804
# Iteration 854: Cost = 941.782959
# Iteration 855: Cost = 941.779297
# Iteration 856: Cost = 941.775452
# Iteration 857: Cost = 941.771667
# Iteration 858: Cost = 941.768005
# Iteration 859: Cost = 941.764160
# Iteration 860: Cost = 941.760376
# Iteration 861: Cost = 941.756592
# Iteration 862: Cost = 941.752869
# Iteration 863: Cost = 941.749207
# Iteration 864: Cost = 941.745361
# Iteration 865: Cost = 941.741577
# Iteration 866: Cost = 941.737854
# Iteration 867: Cost = 941.734070
# Iteration 868: Cost = 941.730286
# Iteration 869: Cost = 941.726562
# Iteration 870: Cost = 941.722778
# Iteration 871: Cost = 941.718994
# Iteration 872: Cost = 941.715149
# Iteration 873: Cost = 941.711365
# Iteration 874: Cost = 941.707703
# Iteration 875: Cost = 941.703979
# Iteration 876: Cost = 941.700195
# Iteration 877: Cost = 941.696350
# Iteration 878: Cost = 941.692566
# Iteration 879: Cost = 941.688782
# Iteration 880: Cost = 941.684998
# Iteration 881: Cost = 941.681396
# Iteration 882: Cost = 941.677551
# Iteration 883: Cost = 941.673767
# Iteration 884: Cost = 941.669983
# Iteration 885: Cost = 941.666199
# Iteration 886: Cost = 941.662354
# Iteration 887: Cost = 941.658752
# Iteration 888: Cost = 941.654968
# Iteration 889: Cost = 941.651184
# Iteration 890: Cost = 941.647400
# Iteration 891: Cost = 941.643555
# Iteration 892: Cost = 941.639771
# Iteration 893: Cost = 941.636169
# Iteration 894: Cost = 941.632385
# Iteration 895: Cost = 941.628601
# Iteration 896: Cost = 941.624756
# Iteration 897: Cost = 941.620972
# Iteration 898: Cost = 941.617188
# Iteration 899: Cost = 941.613586
# Iteration 900: Cost = 941.609802
# Iteration 901: Cost = 941.605957
# Iteration 902: Cost = 941.602173
# Iteration 903: Cost = 941.598389
# Iteration 904: Cost = 941.594604
# Iteration 905: Cost = 941.590881
# Iteration 906: Cost = 941.587158
# Iteration 907: Cost = 941.583374
# Iteration 908: Cost = 941.579590
# Iteration 909: Cost = 941.575806
# Iteration 910: Cost = 941.571960
# Iteration 911: Cost = 941.568359
# Iteration 912: Cost = 941.564575
# Iteration 913: Cost = 941.560791
# Iteration 914: Cost = 941.556946
# Iteration 915: Cost = 941.553162
# Iteration 916: Cost = 941.549377
# Iteration 917: Cost = 941.545776
# Iteration 918: Cost = 941.541992
# Iteration 919: Cost = 941.538147
# Iteration 920: Cost = 941.534363
# Iteration 921: Cost = 941.530701
# Iteration 922: Cost = 941.526855
# Iteration 923: Cost = 941.523193
# Iteration 924: Cost = 941.519348
# Iteration 925: Cost = 941.515564
# Iteration 926: Cost = 941.511780
# Iteration 927: Cost = 941.508057
# Iteration 928: Cost = 941.504272
# Iteration 929: Cost = 941.500488
# Iteration 930: Cost = 941.496765
# Iteration 931: Cost = 941.492981
# Iteration 932: Cost = 941.489197
# Iteration 933: Cost = 941.485352
# Iteration 934: Cost = 941.481689
# Iteration 935: Cost = 941.477905
# Iteration 936: Cost = 941.474182
# Iteration 937: Cost = 941.470398
# Iteration 938: Cost = 941.466553
# Iteration 939: Cost = 941.462891
# Iteration 940: Cost = 941.459106
# Iteration 941: Cost = 941.455383
# Iteration 942: Cost = 941.451599
# Iteration 943: Cost = 941.447754
# Iteration 944: Cost = 941.444092
# Iteration 945: Cost = 941.440247
# Iteration 946: Cost = 941.436462
# Iteration 947: Cost = 941.432800
# Iteration 948: Cost = 941.428955
# Iteration 949: Cost = 941.425171
# Iteration 950: Cost = 941.421448
# Iteration 951: Cost = 941.417664
# Iteration 952: Cost = 941.413879
# Iteration 953: Cost = 941.410095
# Iteration 954: Cost = 941.406372
# Iteration 955: Cost = 941.402588
# Iteration 956: Cost = 941.398804
# Iteration 957: Cost = 941.395081
# Iteration 958: Cost = 941.391296
# Iteration 959: Cost = 941.387573
# Iteration 960: Cost = 941.383789
# Iteration 961: Cost = 941.380005
# Iteration 962: Cost = 941.376282
# Iteration 963: Cost = 941.372375
# Iteration 964: Cost = 941.368774
# Iteration 965: Cost = 941.364990
# Iteration 966: Cost = 941.361206
# Iteration 967: Cost = 941.357361
# Iteration 968: Cost = 941.353699
# Iteration 969: Cost = 941.349854
# Iteration 970: Cost = 941.346069
# Iteration 971: Cost = 941.342346
# Iteration 972: Cost = 941.338562
# Iteration 973: Cost = 941.334778
# Iteration 974: Cost = 941.331055
# Iteration 975: Cost = 941.327393
# Iteration 976: Cost = 941.323547
# Iteration 977: Cost = 941.319763
# Iteration 978: Cost = 941.315979
# Iteration 979: Cost = 941.312195
# Iteration 980: Cost = 941.308350
# Iteration 981: Cost = 941.304688
# Iteration 982: Cost = 941.300964
# Iteration 983: Cost = 941.297180
# Iteration 984: Cost = 941.293396
# Iteration 985: Cost = 941.289551
# Iteration 986: Cost = 941.285889
# Iteration 987: Cost = 941.282166
# Iteration 988: Cost = 941.278381
# Iteration 989: Cost = 941.274597
# Iteration 990: Cost = 941.270752
# Iteration 991: Cost = 941.267090
# Iteration 992: Cost = 941.263367
# Iteration 993: Cost = 941.259583
# Iteration 994: Cost = 941.255798
# Iteration 995: Cost = 941.251953
# Iteration 996: Cost = 941.248169
# Iteration 997: Cost = 941.244446
# Iteration 998: Cost = 941.240662
# Iteration 999: Cost = 941.237000
# Iteration 1000: Cost = 941.233154
# Iteration 10001: Cost = 907.951172
# Iteration 20001: Cost = 872.359497
# Iteration 30001: Cost = 838.169006
# Iteration 40001: Cost = 805.324707
# iteration stopped at step:  49999
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
